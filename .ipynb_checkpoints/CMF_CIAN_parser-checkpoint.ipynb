# %% [markdown]
# # CIAN.ru

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
def html_stripper(text):
    return re.sub('<[^<]+?>', '', str(text))

# %%
page = 1

# %% [markdown]
# ### Для ЦАО находим главную ссылку и в ней находим **&p=1&**, это и есть переход по страницам

# %%
district = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=13&district%5B1%5D=14&district%5B2%5D=15&district%5B3%5D=16&district%5B4%5D=17&district%5B5%5D=18&district%5B6%5D=19&district%5B7%5D=20&district%5B8%5D=21&district%5B9%5D=22&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district
# Out:
# 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=13&district%5B1%5D=14&district%5B2%5D=15&district%5B3%5D=16&district%5B4%5D=17&district%5B5%5D=18&district%5B6%5D=19&district%5B7%5D=20&district%5B8%5D=21&district%5B9%5D=22&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %% [markdown]
# ### Гуляем по страницам и качаем с них все ссылки на наши квартирки

# %%
links = []
for page in range(1, 30):
    page_url =  district.format(page)

    search_page = requests.get(page_url)
    search_page = search_page.content
    search_page = BeautifulSoup(search_page, 'lxml')

    flat_urls = search_page.findAll('div', attrs = {'ng-class':"{'serp-item_removed': offer.remove.state, 'serp-item_popup-opened': isPopupOpen}"})
    flat_urls = re.split('http://www.cian.ru/sale/flat/|/" ng-class="', str(flat_urls))

    for link in flat_urls:
        if link.isdigit():
            links.append(link)

# %%
links
# Out:
# ['148983675',
#  '149810968',
#  '150593190',
#  '149031353',
#  '149031259',
#  '150346368',
#  '148567438',
#  '149031296',
#  '149023045',
#  '148794719',
#  '150094319',
#  '149849414',
#  '149300855',
#  '145609912',
#  '149788538',
#  '149727197',
#  '149431030',
#  '149031382',
#  '148708005',
#  '149031327',
#  '150388419',
#  '150463857',
#  '148800467',
#  '149023309',
#  '149031347',
#  '148112883',
#  '147183006',
#  '149031358',
#  '147727772',
#  '50164495',
#  '150531884',
#  '150118457',
#  '149812301',
#  '149023307',
#  '149031349',
#  '149565205',
#  '150582702',
#  '150260995',
#  '149031380',
#  '149031376',
#  '149031330',
#  '150290526',
#  '150459322',
#  '150462440',
#  '149031362',
#  '150458958',
#  '150377830',
#  '150378060',
#  '19220848',
#  '150411534',
#  '149031338',
#  '150495697',
#  '150519279',
#  '150504277',
#  '149808503',
#  '150545360',
#  '149444635',
#  '149887035',
#  '145828928',
#  '149031344',
#  '148829537',
#  '148829580',
#  '149385905',
#  '149031318',
#  '150435931',
#  '149031262',
#  '149063476',
#  '150203517',
#  '149031336',
#  '149936525',
#  '149031388',
#  '150052325',
#  '149213362',
#  '149330730',
#  '149031377',
#  '148708004',
#  '150043158',
#  '149507258',
#  '149507223',
#  '149031373',
#  '136574524',
#  '147872339',
#  '146275883',
#  '149390159',
#  '150537921',
#  '149883045',
#  '150236129',
#  '150474445',
#  '149434931',
#  '149213364',
#  '143167140',
#  '149031276',
#  '148800461',
#  '149808778',
#  '149808771',
#  '149298419',
#  '149031339',
#  '148778282',
#  '149031334',
#  '150118455',
#  '50961163',
#  '147654877',
#  '149881045',
#  '149221936',
#  '144137751',
#  '150110827',
#  '139457465',
#  '149041370',
#  '149041603',
#  '150614690',
#  '148778285',
#  '149041463',
#  '48892646',
#  '149608159',
#  '149813334',
#  '149392347',
#  '46651957',
#  '150520521',
#  '148158445',
#  '150495809',
#  '136694481',
#  '149256580',
#  '149273778',
#  '143792687',
#  '137443463',
#  '150111252',
#  '37630744',
#  '149670358',
#  '142254439',
#  '150121374',
#  '51100663',
#  '148232270',
#  '147072046',
#  '149772475',
#  '147506154',
#  '150335936',
#  '144021578',
#  '48902681',
#  '150221863',
#  '146689434',
#  '149998514',
#  '150521077',
#  '148693701',
#  '150345413',
#  '150609088',
#  '150571945',
#  '149782804',
#  '149782808',
#  '149840531',
#  '149522177',
#  '150046318',
#  '150288474',
#  '149978646',
#  '149670592',
#  '148409759',
#  '149920635',
#  '150240755',
#  '147471757',
#  '150403802',
#  '150462536',
#  '51775164',
#  '150096855',
#  '150436781',
#  '148053764',
#  '50192443',
#  '149782795',
#  '149782811',
#  '139175915',
#  '138125476',
#  '150097714',
#  '150126125',
#  '150101949',
#  '150296850',
#  '149771498',
#  '148511392',
#  '149311866',
#  '150379207',
#  '149327524',
#  '26309806',
#  '150300672',
#  '148868336',
#  '150078077',
#  '150465669',
#  '149468142',
#  '150253897',
#  '47470009',
#  '37580368',
#  '39171989',
#  '142254440',
#  '150231878',
#  '142987504',
#  '149319680',
#  '149758363',
#  '49094436',
#  '149638669',
#  '136574434',
#  '150428281',
#  '148633624',
#  '150049090',
#  '149930756',
#  '148689932',
#  '149773978',
#  '149741828',
#  '148255275',
#  '150578948',
#  '150370784',
#  '150375763',
#  '150149866',
#  '145031201',
#  '11840512',
#  '150464047',
#  '150149867',
#  '150378344',
#  '150439990',
#  '150464350',
#  '149858926',
#  '145205143',
#  '148572284',
#  '49549585',
#  '150098553',
#  '148399757',
#  '148073640',
#  '148431320',
#  '150408010',
#  '150412891',
#  '149384451',
#  '147695889',
#  '43472315',
#  '150475470',
#  '149555669',
#  '148282730',
#  '149396952',
#  '150527975',
#  '149725676',
#  '150454619',
#  '150234018']

# %%
len(links)
# Out:
# 812

# %% [markdown]
# Итого вытащили 812 квартирок по ЦАО

# %% [markdown]
# ### Попробуем перейти на первую

# %%
flat_url = 'http://www.cian.ru/sale/flat/' + str(links[0]) + '/'
#flat_url = 'http://www.cian.ru/sale/flat/150531912/' 
flat_page = requests.get(flat_url)
flat_page = flat_page.content
flat_page = BeautifulSoup(flat_page, 'lxml')

# %%
flat_page
# Out:
# <!DOCTYPE html>\n<html class="no-touch">\n<head>\n<meta content="text/html; charset=unicode-escape" http-equiv="Content-Type"/>\n<meta content="Eig23WXwvPZu3gp9EYVreR61rG4TX1bHQDEG0Di5ZSE" name="google-site-verification"/>\n<meta content="\u0426\u0418\u0410\u041d" name="apple-mobile-web-app-title"/>\n<meta content="app-id=911804296, app-argument=http://www.cian.ru/sale/flat/148983675/" name="apple-itunes-app"/>\n<link href="android-app://ru.cian.main/cian/offer/sale/flat/148983675/" rel="alternate"/>\n<meta content="cian://sale/flat/148983675/" property="al:ios:url"/>\n<meta content="911804296" property="al:ios:app_store_id"/>\n<meta content="Cian" property="al:ios:app_name"/>\n<meta content="http://www.cian.ru/sale/flat/148983675/" property="al:android:url"/>\n<meta content="Cian" property="al:android:app_name"/>\n<meta content="ru.cian.main" property="al:android:package"/>\n<meta content="http://www.cian.ru/sale/flat/148983675/" property="al:web:url"/>\n<meta content="website" property="og:type"/>\n<meta content="CIAN" property="og:site_name"/>\n<meta content="\u041f\u0440\u043e\u0434\u0430\u0435\u0442\u0441\u044f 1-\u043a\u043e\u043c\u043d\u0430\u0442\u043d\u0430\u044f \u043a\u0432\u0430\u0440\u0442\u0438\u0440\u0430 \u0437\u0430 27 106 000 \u0440\u0443\u0431., 57.3 \u043c\xb2, \u044d\u0442\u0430\u0436 4/6" property="og:title"/>\n<meta content="http://cdn5.cian.ru/1/764/251/kvartira-moskva-sadovnicheskaya-naberezhnaya-152467153-1.jpg" property="og:image"/>\n<meta content="http://www.cian.ru/sale/flat/148983675/" property="og:url"/>\n<meta content="\u041f\u0440\u043e\u0434\u0430\u044e\u0442\u0441\u044f \u0430\u043f\u0430\u0440\u0442\u0430\u043c\u0435\u043d\u0442\u044b 57.3 \u043a\u0432.\u043c \u0432 \u043d\u043e\u0432\u043e\u043c \u044d\u043b\u0438\u0442\u043d\u043e\u043c \u0430\u043f\u0430\u0440\u0442-\u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441\u0435 \u0440\u0430\u0439\u043e\u043d\u0430 \u0417\u0430\u043c\u043e\u0441\u043a\u0432\u043e\u0440\u0435\u0447\u044c\u0435 \u043d\u0430 \u043e\u0441\u0442\u0440\u043e\u0432\u0435 \u0411\u0430\u043b\u0447\u0443\u0433. \u0412 \u043a\u0432\u0430\u0440\u0442\u0438\u0440\u0435 \u0441\u0432\u043e\u0431\u043e\u0434\u043d\u0430\u044f \u043f\u043b\u0430\u043d\u0438\u0440\u043e\u0432\u043a\u0430, \u043f\u0430\u043d\u043e\u0440\u0430\u043c\u043d\u043e\u0435 \u043e\u0441\u0442\u0435\u043a\u043b\u0435\u043d\u0438\u0435, \u0432\u044b\u0441\u043e\u043a\u0438\u0435 \u043f\u043e\u0442\u043e\u043b\u043a\u0438. \u041a\u043e\u043c\u043f\u043b\u0435\u043a\u0441 \u043e\u0441\u043d\u0430\u0449\u0435\u043d \u0441\u043e\u0432\u0440\u0435\u043c\u0435\u043d\u043d\u044b\u043c\u0438 \u0441\u0438\u0441\u0442\u0435\u043c\u0430\u043c\u0438 \u0431\u0435\u0437\u043e\u043f\u0430\u0441\u043d\u043e\u0441\u0442\u0438, \u0432\u0438\u0434\u0435\u043e\u043d\u0430\u0431\u043b\u044e\u0434\u0435\u043d\u0438\u044f. \u0414\u0432\u0443\u0445\u0443\u0440\u043e\u0432\u043d\u0435\u0432\u044b\u0439 \u043f\u043e\u0434\u0437\u0435\u043c\u043d\u044b\u0439 \u043f\u0430\u0440\u043a\u0438\u043d\u0433, \u043e\u0433\u043e\u0440\u043e\u0436\u0435\u043d\u043d\u0430\u044f \u043e\u0445\u0440\u0430\u043d\u044f\u0435\u043c\u0430\u044f \u0442\u0435\u0440\u0440\u0438\u0442\u043e\u0440\u0438\u044f. \u0411\u043e\u0433\u0430\u0442\u0430\u044f \u0438\u043d\u0444\u0440\u0430\u0441\u0442\u0440\u0443\u043a\u0442\u0443\u0440\u0430 \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441\u0430 \u0438 \u043e\u043a\u0440\u0435\u0441\u0442\u043d\u043e\u0441\u0442\u0435\u0439. \u0410\u043f\u0430\u0440\u0442\u0430\u043c\u0435\u043d\u0442\u044b \u0432 \u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0446\u0438\u0438 \u0411\u0430\u043b\u0447\u0443\u0433 \u0432 \u043d\u0435\u0441\u043a\u043e\u043b\u044c\u043a\u0438\u0445 \u0448\u0430\u0433\u0430\u0445 \u043e\u0442 \u041a\u0440\u0435\u043c\u043b\u044f \u044d\u0442\u043e \u043e\u0442\u043b\u0438\u0447\u043d\u0430\u044f \u0432\u043e\u0437\u043c\u043e\u0436\u043d\u043e\u0441\u0442\u044c \u0436\u0438\u0442\u044c \u0438 \u0440\u04 ...

# %%
flatStats = {'District':0}

# %% [markdown]
# # Цена

# %%
price = flat_page.find('div', attrs={'class':'object_descr_price'})
price = re.split('<div>|за м<sup>2</sup>|\n|руб|\W', str(price))

# %%
print(price)
# Out:
# ['', 'div', 'class', '', 'object_descr_price', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '27', '106', '000', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'div', '']

# %%
[i for i in price if i.isdigit()]
# Out:
# ['2', '7', '1', '0', '6', '0', '0', '0']

# %%
"".join([i for i in price if i.isdigit()][-3:])
# Out:
# '27106000'

# %%
price = "".join([i for i in price if i.isdigit()][-3:])

# %%
price
# Out:
# '27106000'

# %%
def getPrice(flat_page):
    price = flat_page.find('div', attrs={'class':'object_descr_price'})
    price = re.split('<div>|руб|\W', str(price))
    price = "".join([i for i in price if i.isdigit()][-3:])
    return int(price)

# %%
getPrice(flat_page)
# Out:
# 27106000

# %%
flatStats['Price'] = getPrice(flat_page)

# %%
flatStats
# Out:
# {'District': 0, 'Price': 27106000}

# %% [markdown]
# # Координаты

# %%
flat_page.find('div', attrs={'class':'map_info_button_extend'}).contents[1]
# Out:
# <a href="http://map.cian.ru/?deal_type=2&amp;flats=yes&amp;center=55.747211%2C37.627301&amp;room0=1&amp;room1=1" rel="nofollow" target="_blank"><i></i>\u041f\u043e\u0441\u043c\u043e\u0442\u0440\u0435\u0442\u044c \u043f\u0440\u0435\u0434\u043b\u043e\u0436\u0435\u043d\u0438\u044f \u0440\u044f\u0434\u043e\u043c</a>

# %%
coords = flat_page.find('div', attrs={'class':'map_info_button_extend'}).contents[1]
coords = re.split('&amp|center=|%2C', str(coords))
coords_list = []
for item in coords:
    if item[0].isdigit():
        coords_list.append(item)
lat = float(coords_list[0])
lon = float(coords_list[1])

# %%
lat, lon
# Out:
# (55.747211, 37.627301)

# %%
def getCoords(flat_page):
    coords = flat_page.find('div', attrs={'class':'map_info_button_extend'}).contents[1]
    coords = re.split('&amp|center=|%2C', str(coords))
    coords_list = []
    for item in coords:
        if item[0].isdigit():
            coords_list.append(item)
    lat = float(coords_list[0])
    lon = float(coords_list[1])
    return lat, lon

# %%
getCoords(flat_page)
# Out:
# (55.747211, 37.627301)

# %%
flatStats['lat'], flatStats['lon'] = getCoords(flat_page)

# %%
flatStats
# Out:
# {'District': 0, 'Price': 27106000, 'lat': 55.747211, 'lon': 37.627301}

# %% [markdown]
# # Число комнат

# %%
rooms = flat_page.find('div', attrs={'class':'object_descr_title'})

# %%
flat_url
# Out:
# 'http://www.cian.ru/sale/flat/148983675/'

# %%
rooms
# Out:
# <div class="object_descr_title" itemprop="name">\n                \n    \n        1-\u043a\u043e\u043c\u043d. \u043a\u0432.\xa0\n    \n\n                \n                    \n                \n                </div>

# %%
rooms = html_stripper(rooms)

# %%
rooms
# Out:
# '\n                \n    \n        1-\xd0\xba\xd0\xbe\xd0\xbc\xd0\xbd. \xd0\xba\xd0\xb2.\xc2\xa0\n    \n\n                \n                    \n                \n                '

# %%
re.split('-|\n', rooms)
# Out:
# ['',
#  '                ',
#  '    ',
#  '        1',
#  '\xd0\xba\xd0\xbe\xd0\xbc\xd0\xbd. \xd0\xba\xd0\xb2.\xc2\xa0',
#  '    ',
#  '',
#  '                ',
#  '                    ',
#  '                ',
#  '                ']

# %%
room_number = ''
for i in re.split('-|\n', rooms):
    if 'комн' in i:
        break
    else:
        room_number += i
room_number = "".join(room_number.split())

# %%
room_number
# Out:
# '1'

# %%
def getRoom(flat_page):
    rooms = flat_page.find('div', attrs={'class':'object_descr_title'})
    rooms = html_stripper(rooms)
    room_number = ''
    for i in re.split('-|\n', rooms):
        if 'комн' in i:
            break
        else:
            room_number += i
    room_number = "".join(room_number.split())
    return room_number

# %%
getRoom(flat_page)
# Out:
# '1'

# %%
flatStats['rooms'] = getRoom(flat_page)

# %%
flatStats
# Out:
# {'District': 0,
#  'Price': 27106000,
#  'lat': 55.747211,
#  'lon': 37.627301,
#  'rooms': '1'}

# %% [markdown]
# # Таблица

# %%
table = flat_page.find('table', attrs = {'class':'object_descr_props'})

# %%
table
# Out:
# <table class="object_descr_props flat sale" style="float:left">\n<tr>\n<th style="padding-top:5px;"> # \u041e\u0431\u0449\u0430\u044f \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u044f:</th>\n</tr>\n<tr>\n<th>\u0421\u0442\u0430\u0442\u0443\u0441 \u043f\u043e\u043c\u0435\u0449\u0435\u043d\u0438\u044f:</th>\n<td>\u0430\u043f\u0430\u0440\u0442\u0430\u043c\u0435\u043d\u0442\u044b</td>\n</tr>\n<tr>\n<th>\u042d\u0442\u0430\u0436:</th>\n<td>\n                4\xa0/\xa06\n                \n            </td>\n</tr>\n<tr>\n<th>\u0422\u0438\u043f \u0434\u043e\u043c\u0430:</th>\n<td>\n            \u0432\u0442\u043e\u0440\u0438\u0447\u043a\u0430, \n            \u043c\u043e\u043d\u043e\u043b\u0438\u0442\u043d\u044b\u0439\n        </td>\n</tr>\n<tr>\n<th>\u0422\u0438\u043f \u043f\u0440\u043e\u0434\u0430\u0436\u0438:</th>\n<td>\u0441\u0432\u043e\u0431\u043e\u0434\u043d\u0430\u044f</td>\n</tr>\n<tr>\n<th>\u041e\u0431\u0449\u0430\u044f \u043f\u043b\u043e\u0449\u0430\u0434\u044c:</th>\n<td>\n<i class="object_descr_details_color"></i>57,3\xa0\u043c<sup>2</sup>\n</td>\n</tr>\n<tr>\n<th>\u041f\u043b\u043e\u0449\u0430\u0434\u044c \u043a\u043e\u043c\u043d\u0430\u0442:</th>\n<td>\n<i class="object_descr_details_color"></i><!--\n-->40,5\xa0\u043c<sup>2</sup>\n</td>\n</tr>\n<tr>\n<th>\u0416\u0438\u043b\u0430\u044f \u043f\u043b\u043e\u0449\u0430\u0434\u044c:</th>\n<td>\n<i class="object_descr_details_color" style="background-color:#90C090"></i>40,5\xa0\u043c<sup>2</sup>\n</td>\n</tr>\n<tr>\n<th>\u041f\u043b\u043e\u0449\u0430\u0434\u044c \u043a\u0443\u0445\u043d\u0438:</th>\n<td>\n<i class="object_descr_details_color" style="background-color:#C09090"></i>\u2013\n        </td>\n</tr>\n<tr>\n<th>\u0421\u043e\u0432\u043c\u0435\u0449\u0435\u043d\u043d\u044b\u0445 \u0441\u0430\u043d\u0443\u0437\u043b\u043e\u0432:</th>\n<td><i class="object_descr_details_color" style="background-color:#90C0C0"></i>1\n            </td>\n</tr>\n<tr>\n<th>\u0411\u0430\u043b\u043a\u043e\u043d:</th>\n<td><i class="object_descr_details_color" style="background-color:#C0C0C0"></i>1 \u043b\u043e\u0434\u0436.\n        </td>\n</tr>\n<tr>\n<th>\u041b\u0438\u0444\u0442:</th>\n<td>1 \u043f\u0430\u0441\u0441. + 1 \u0433\u0440\u0443\u0437.</td>\n</tr>\n<tr>\n<th>\u0412\u0438\u0434 \u0438\u0437 \u043e\u043a\u043d\u0430:</th>\n<td>\u0443\u043b\u0438\u0446\u0430</td>\n</tr>\n<tr>\n<th>\u0420\u0435\u043c\u043e\u043d\u0442:</th>\n<td>\u043e\u0442\u0441\u0443\u0442\u0441\u0442\u0432\u0443\u0435\u0442</td>\n</tr>\n</table>

# %%
print(html_stripper(table))
# Out:
#  # Общая информация:
#
#
# Статус помещения:
# апартаменты
#
#
# Этаж:
#
#                 4 / 6
#
#
#
#
# Тип дома:
#
#             вторичка,
#             монолитный
#
#
#
# Тип продажи:
# свободная
#
#
# Общая площадь:
#
# 57,3 м2
#
#
#
# Площадь комнат:
#
# 40,5 м2
#
#
#
# Жилая площадь:
#
# 40,5 м2
#
#
#
# Площадь кухни:
#
# –
#
#
#
# Совмещенных санузлов:
# 1
#
#
#
# Балкон:
# 1 лодж.
#
#
#
# Лифт:
# 1 пасс. + 1 груз.
#
#
# Вид из окна:
# улица
#
#
# Ремонт:
# отсутствует

# %%
table = html_stripper(table)

# %%
print(re.split('Этаж|Тип дома', table)[1])
# Out:
# :
#
#                 4 / 6
