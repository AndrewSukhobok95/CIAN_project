= 'http://www.cian.ru/cat.php?deal_type=rent&district%5B0%5D=125&district%5B1%5D=126&\
district%5B2%5D=127&district%5B3%5D=128&district%5B4%5D=129&district%5B5%5D=130&district%5B6%5D=131&\
district%5B7%5D=132&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&type=4'

# %%
# Only 11 pages
district_nao = 'http://www.cian.ru/cat.php?deal_type=rent&district%5B0%5D=327&district%5B1%5D=328&\
district%5B10%5D=337&district%5B2%5D=329&district%5B3%5D=330&district%5B4%5D=331&district%5B5%5D=332&\
district%5B6%5D=333&district%5B7%5D=334&district%5B8%5D=335&district%5B9%5D=336&engine_version=2&offer_type=flat&\
p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&type=4'

# %%
# Only 2 pages
district_tao = 'http://www.cian.ru/cat.php?deal_type=rent&district%5B0%5D=338&district%5B1%5D=339&district%5B2%5D=340&\
district%5B3%5D=341&district%5B4%5D=342&district%5B5%5D=343&district%5B6%5D=344&district%5B7%5D=345&district%5B8%5D=346&\
district%5B9%5D=347&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&type=4'

# %%
district = [district_cao, district_sao, district_svao, district_vao, district_uvao, district_uao, district_uzao,
            district_zao, district_szao, district_nao, district_tao]

# %% [markdown]
# ### Сбор ссылок

# %%
# d отвечает за район - этот параметр будет нужен для сбора по районам
def page_grabber(page, d=0):
    flats_links = [] # список с ссылками с одной страницы поиска
    p = len(page)
    for i in range(p):
        flats_links.append((page[i].attrs['href'], d)) # один элемент - ссылка (то есть атрибут href тега div)
    return(flats_links)

# %%
def district_page_grabber(district, j=0):
    
    links = [] # Список, который заполним всеми квартирами (только те, что размещены внутри самомго сайта)
    
    if district == district_nao:
        n_pages = 12
    elif district == district_tao:
        n_pages = 3
    else:
        n_pages = 31
    
    for i in range(1,n_pages):
        # Получаем нужную страницу
        search_page = requests.get(district.format(i))
        search_page = search_page.text
        search_page = BeautifulSoup(search_page, 'lxml')

        # Внутри нужной страницы добираемся до таблицы с квартирами
        flats = search_page.html.body.findAll('div', id='content')
        flats = flats[0].findAll('div', attrs = {'class':'serp-list'})

        # В этой переменной будет лежать нужный кусок страницы (в каждой итерации новая страница)
        flats_cian = flats[0].findAll('div',\
                  attrs = {'ng-class':"{'serp-item_removed': offer.remove.state, 'serp-item_popup-opened': isPopupOpen}"})

        # Берем ссылки с текущей страницы и кладем в наш общий список ссылок
        links = links + page_grabber(flats_cian, d=j)

        # Каждую итерацию проверяем, что все нормально работает 
        print('Page_{}_ok_Iter={}'.format(i,j))
        
    return(links)

# %%
l = len(district)
j = 0

links = []

for dist in range(l):
    
    links = links + district_page_grabber(district[dist], j=j)
    
    j += 1
# Out:
# Page_1_ok_Iter=0
# Page_2_ok_Iter=0
# Page_3_ok_Iter=0
# Page_4_ok_Iter=0
# Page_5_ok_Iter=0
# Page_6_ok_Iter=0
# Page_7_ok_Iter=0
# Page_8_ok_Iter=0
# Page_9_ok_Iter=0
# Page_10_ok_Iter=0
# Page_11_ok_Iter=0
# Page_12_ok_Iter=0
# Page_13_ok_Iter=0
# Page_14_ok_Iter=0
# Page_15_ok_Iter=0
# Page_16_ok_Iter=0
# Page_17_ok_Iter=0
# Page_18_ok_Iter=0
# Page_19_ok_Iter=0
# Page_20_ok_Iter=0
# Page_21_ok_Iter=0
# Page_22_ok_Iter=0
# Page_16_ok_Iter=7
# Page_17_ok_Iter=7
# Page_18_ok_Iter=7
# Page_19_ok_Iter=7
# Page_20_ok_Iter=7
# Page_21_ok_Iter=7
# Page_22_ok_Iter=7
# Page_23_ok_Iter=7
# Page_24_ok_Iter=7
# Page_25_ok_Iter=7
# Page_26_ok_Iter=7
# Page_27_ok_Iter=7
# Page_28_ok_Iter=7
# Page_29_ok_Iter=7
# Page_30_ok_Iter=7
# Page_1_ok_Iter=8
# Page_2_ok_Iter=8
# Page_3_ok_Iter=8
# Page_4_ok_Iter=8
# Page_5_ok_Iter=8
# Page_6_ok_Iter=8
# Page_7_ok_Iter=8
# Page_8_ok_Iter=8
# Page_9_ok_Iter=8
# Page_10_ok_Iter=8
# Page_11_ok_Iter=8
# Page_12_ok_Iter=8
# Page_13_ok_Iter=8
# Page_14_ok_Iter=8
# Page_15_ok_Iter=8
# Page_16_ok_Iter=8
# Page_17_ok_Iter=8
# Page_18_ok_Iter=8
# Page_19_ok_Iter=8
# Page_20_ok_Iter=8
# Page_21_ok_Iter=8
# Page_22_ok_Iter=8
# Page_23_ok_Iter=8
# Page_24_ok_Iter=8
# Page_25_ok_Iter=8
# Page_26_ok_Iter=8
# Page_27_ok_Iter=8
# Page_28_ok_Iter=8
# Page_29_ok_Iter=8
# Page_30_ok_Iter=8
# Page_1_ok_Iter=9
# Page_2_ok_Iter=9
# Page_3_ok_Iter=9
# Page_4_ok_Iter=9
# Page_5_ok_Iter=9
# Page_6_ok_Iter=9
# Page_7_ok_Iter=9
# Page_8_ok_Iter=9
# Page_9_ok_Iter=9
# Page_10_ok_Iter=9
# Page_11_ok_Iter=9
# Page_1_ok_Iter=10
# Page_2_ok_Iter=10

# %%
links = list(set(links))

# %%
with open('links_lease.txt', 'a') as f:
    for i in range(len(links)):
        f.write(links[i][0] + ' dist=' + str(links[i][1]) + '\n')

# %%
links = []

# %%
with open('links_lease.txt') as f:
    for line in f:
        line = (re.findall(r'.+ dist', line)[0][:-5], \
               int(re.findall(r'dist=\d+', line)[0][5:]))
        links.append(line)

# %%
len(links)
# Out:
# 14350

# %% [markdown]
# ### Функции

# %%
def room_grabber(table):
    room = table.findAll('div', class_='object_descr_title')
    try:
        room = re.findall(r'.?-комн. кв.' ,str(room[0]))[0]
    except:
        if re.findall(r'многокомн' ,str(room[0]))[0] == 'многокомн':
            room = [6]
    return(int(room[0]))

# %%
def price_grabber(table):
    '''
    Будем возвращать цену списком. Судя по всему ЦИАН предоставил нам скрытый тег, в котором лежит цена в удобном для нас
    виде - на всякий случай будем собирать цену в двух вариантах (можно будет проверить + если один вариант отпал - другой будет доступен).
    В качестве нулевых значений возьмем NaN
    '''
    price1 = table.findAll('div', class_='object_descr_price')[0]
    price2 = price1.findNext()
    
    p1 = np.nan
    p2 = np.nan
    
    try:
        p1 = price1.string.strip()
        p1 = re.findall(r'.+руб', p1)[0]
        p1 = p1[:-4]
        p1 = p1.replace(' ', '')
        p1 = float(p1)
    except:
        pass
    
    try:
        p2 = price2.string.strip()
        p2 = float(p2.replace(',', '.'))
    except:
        pass
    
    return([p1,p2])

# %%
def metro(table):
    try:
        # Нужный кусок html
        metro = table.findAll('div', class_='object_descr_metro')
        metro_name = metro[0].findAll('a', class_='object_item_metro_name')[0]
        metro = metro[0].findAll('span', class_='object_item_metro_comment')[0].string
        
        # Название станции
        name = metro_name.string[:-1]
        
        # Минуты
        metrdist = int(re.findall(r'\d+', metro)[0])

        # Walk
        walk = metro.replace(' ', '')
        walk = walk.replace('\n', '')
        walk = re.findall(r'мин\..+', walk)[0][4:]
        if walk == 'пешком':
            walk = 1
        elif walk == []:
            walk = np.nan
        else:
            walk = 0
    except:
        metrdist = np.nan
        walk = np.nan
        name = np.nan
        
    return({'metrdist': metrdist, 'walk': walk, 'stname': name})

# %%
def brick_grabber(flat_page):
    
    # Ищем на странице нужный кусок html кода
    house_table = flat_page.findAll('div', class_='offer_container object_descr cleared')
    house_table = house_table[0].findAll('div', class_='bti__inner')
    
    # Проверка на случай, если искомая секция вобще отсутствует на странице данной квартиры
    if house_table == []:
        brick = np.nan
    else:
        # Углубляемся в нужный кусок html кода
        first_table = house_table[0].findAll('tbody')[0]
        first_table_tr = first_table.findAll('tr') # Собрали все tr, то есть все секции первой малой таблицы

        #Ищем нужный th с информацией о материале
        for i in range(1,len(first_table_tr)):
            try:
                brick_str = re.findall(r'Материалы стен', str(first_table_tr[i].th))[0]
                if brick_str == 'Материалы стен':
                    # Ищем один из нужных нам флажков - кирпич, монолит или варианты ж/б
                    brick = re.findall(r'кирпич|монолит|ж??б|желез.+бетон', str(first_table_tr[i].td))
            except:
                pass

        # Проверяем результат регулярного выражения
        if len(brick) == 0:
            brick = 0
        else:
            brick = 1
        
    return(brick)

# %%
def getCoords(flat_page):
    coords = flat_page.find('div', attrs={'class':'map_info_button_extend'}).contents[1]
    coords = re.split('&amp|center=|%2C', str(coords))
    coords_list = []
    for item in coords:
        if item[0].isdigit():
            coords_list.append(item)
    lat = float(coords_list[0])
    lon = float(coords_list[1])
    return lat, lon

def dist_grabber(house_coords):
    null_coords = (55.755831, 37.617673)
    
    # Радиус Земли
    R = 6371
    
    # Широта (latitude):
    lat1 = house_coords[0]
    lat2 = null_coords[0]

    # Долгота (longtude):
    lon1 = house_coords[1]
    lon2 = null_coords[1]
    
    d = np.arccos(
    np.sin(lat1)*np.sin(lat2) + np.cos(lat1)*np.cos(lat2)*np.cos(lat1-lat2)
    )
    L = d*R
    return(L)

# %%
def sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь']):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    # Список, куда будем класть наши значения искомых площадей
    sp_list = []
    
    # Перебираем три метста
    for s in sp_pl:
        
        # Поиск нужной цифры
        for i in range(1,len(table_td)):
            try:
                sp_str = re.findall(r'{}'.format(s) ,table_td[i].th.string)[0] # В качестве s ставим искмую сейчас площадь
                if sp_str == '{}'.format(s):
                    sp = re.findall(r'\d+\,?\d+\xa0м', str(table_td[i].td))

                    # Надстройка на случай, если графа с площадью пуста
                    if sp == []:
                        sp = np.nan
                        sp_list.append(sp) # Добавим в список значение так же, если нужной информации нет
                        break

                    sp = sp[0].replace(',', '.')
                    sp = float(re.findall(r'\d+\.?\d+', sp)[0])
                    
                    # Добавим в список значение очередной площади
                    sp_list.append(sp)
            except:
                pass
    
    # Словарь, в котором подпишем цифры удобным названием переменных
    sp_dist = {}
    sp_dist['totsp'] = sp_list[0]
    sp_dist['kitsp'] = sp_list[1]
    sp_dist['livesp'] = sp_list[2]
    
    # Вернем словарь со всеми нужными значениями
    return(sp_dist)

# %%
def floor_grabber(inner_table):
    
    try:
        # Теперь тут лежит внутренняя таблица (список td)
        table_td = inner_table.findAll('tr')

        # Вытаскиваем этажи
        for i in range(1,len(table_td)):
            try:
                th = re.findall(r'Этаж' ,table_td[i].th.string)[0]
                if th == 'Этаж':
                    floor_td = table_td[i].td # тег со всей информацией об этажах
                    floor_td = re.findall(r'\d+', str(floor_td)) # Теперь в переенной лежит список
                    # Одно число - только этаж квартиры, Два - еще суммарное количество этажей, Пустой - этой информции нет
            except:
                pass

        # Определяем какую информацию дать на выход
        if len(floor_td) == 0:
            floor = np.nan
            nfloor = np.nan
        elif len(floor_td) == 1:
            floor = int(floor_td[0])
            nfloor = np.nan
        else:
            floor = int(floor_td[0])
            nfloor = int(floor_td[1])
    except:
        floor = np.nan
        nfloor = np.nan

    return({'floor':floor, 'n_floor':nfloor})

# %%
def bal_grabber(inner_table):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    #Ищем нужный th с общей площадью квартиры
    for i in range(1,len(table_td)):
        # Положим сюда строку "Балкон" и поней будем искать нужный th
        # (на случай, если кол-во параметров может отличаться в разных квартирах)
        try:
            bal_str = re.findall(r'Балкон' ,table_td[i].th.string)[0]
            if bal_str == 'Балкон':
                bal = re.findall(r'i>\d+|есть', str(table_td[i].td))# Найдем кусок с метрами
                # Если балконов нет, то реулярное выражение ничего не найдет и вернет пустой список
                if bal == []:
                    bal = 0
                else:
                    bal = 1
        except:
            pass
        
    return(bal)

# %%
def tel_grabber(inner_table):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    # На некоторых страницах отстутствует графа "Телефон", поэтому введем проверку на наличие этой строки с помощью индикатора
    th_count = 0
    
    # Смотрим на td в поисках графы "Телефон"
    for i in range(1,len(table_td)):
        try:
            # Накручиваем значение индикатора
            th_count = th_count + 1
            
            th = re.findall(r'Телефон' ,table_td[i].th.string)[0]
            
            if th == 'Телефон':
                th_count = 0
                
                tel = table_td[i].td.string
                
                # Проверка на текст в нужном куске html кода
                if tel == 'да':
                    tel = 1
                else:
                    tel = 0
        except:
            pass
    
    # Проверка индикатора
    if th_count == len(table_td)-1:
        tel = 0
    
    return(tel)

# %%
def new_grabber(inner_table):
    
    try:
        # Теперь тут лежит внутренняя таблица (список td)
        table_td = inner_table.findAll('tr')

        # Идем по всем td в поисках графы 'Тип дома'
        for i in range(1,len(table_td)):
            try:
                new_str = re.findall(r'Тип дома' ,table_td[i].th.string)[0]
                if new_str == 'Тип дома':
                    new = re.findall(r'вторич', str(table_td[i].td))

                    # Проверка на наличия корня "вторич" в данной графе таблице
                    if new == []:
                        new = 1
                    else:
                        new = 0
            except:
                pass

        return(new)
    except:
        return(np.nan)

# %%
def small_dist_grabber(flat_page):
    
    # Ищем на странице нужный кусок html кода
    house_table = flat_page.findAll('div', class_='offer_container object_descr cleared')
    house_table = house_table[0].findAll('div', class_='bti__inner')
    
    # Проверка на случай, если искомая секция вобще отсутствует на странице данной квартиры
    if house_table == []:
        s_dist = np.nan
    else:
        # Углубляемся в нужный кусок html кода
        second_table = house_table[0].findAll('div', class_='bti__col')[1]
        second_table = second_table.findAll('tbody')[0]
        second_table_tr = second_table.findAll('tr')

        for i in range(0,len(second_table_tr)):
            try:
                s_dist_str = re.findall(r'Название', str(second_table_tr[i].th))[0]
                if s_dist_str == 'Название':
                    s_dist = second_table_tr[i].td.string
            except:
                pass
        
    return(s_dist)

# %%
def rem_grabber(inner_table):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    rem = np.nan
    
    for i in range(1,len(table_td)):
        try:
            rem_str = re.findall(r'Ремонт' ,table_td[i].th.string)[0]
            if rem_str == 'Ремонт':
                rem = table_td[i].td.string
        except:
            pass
        
    return(rem)

# %% [markdown]
# ### Сбор квартир

# %%
flats_dict = {}
N = 15000

# %%
start = 12000
#end = 12000

# %%
errors = []

for l in links[start:end]:
    
    try:
        # Это будет номер квартиры
        N = N + 1

        # Соберем все, что написано выше, вместе
        flat_page = requests.get(l[0])
        flat_page = flat_page.text
        flat_page = BeautifulSoup(flat_page, 'lxml')
        inf_table = flat_page.findAll('table', class_ = 'object_descr_tab')
        inf_table = inf_table[0]
        inner_table = inf_table.findAll('table', class_ = 'object_descr_props')
        inner_table = inner_table[0]

        house_coords = getCoords(flat_page)

        flats_dict[N] = {
            'Lat': house_coords[0],
            'Lon': house_coords[1],
            'District': l[1],
            'Small_district': small_dist_grabber(flat_page),
            'Rooms': room_grabber(inf_table),
            'Price': price_grabber(inf_table)[0],
            'Price_duplicate': price_grabber(inf_table)[1],
            'Totsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['totsp'],
            'Livesp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['kitsp'],
            'Kitsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['livesp'],
            'Rem': rem_grabber(inner_table),
            'Dist': dist_grabber(house_coords),
            'Stname': metro(inf_table)['stname'],
            'Metrdist': metro(inf_table)['metrdist'],
            'Walk': metro(inf_table)['walk'],
            'Brick': brick_grabber(flat_page),
            'Tel': tel_grabber(inner_table),
            'Bal': bal_grabber(inner_table),
            'Floor': floor_grabber(inner_table)['floor'],
            'Nfloors': floor_grabber(inner_table)['n_floor'],
            'New': new_grabber(inner_table),
            'Link': l[0]
        }

        print('Page {} is working well'.format(N))
        
    except:
        errors.append(N)
        print('Page {} - ERROR!-ERROR!-ERROR!-ERROR!-ERROR!-ERROR!-ERROR!'.format(N))
# Out:
# Page 15001 is working well
# Page 15002 is working well
# Page 15003 is working well
# Page 15004 is working well
# Page 15005 is working well
# Page 15006 is working well
# Page 15007 is working well
# Page 15008 is working well
# Page 15009 is working well
# Page 15010 is working well
# Page 15011 is working well
# Page 15012 is working well
# Page 15013 is working well
# Page 15014 is working well
# Page 15015 is working well
# Page 15016 is working well
# Page 15017 is working well
# Page 15018 is working well
# Page 15019 is working well
# Page 15020 is working well
# Page 15021 is working well
# Page 15022 is working well
# Page 15023 is working well
# Page 15024 is working well
# Page 15025 is working well
# Page 15026 is working well
# Page 15027 is working well
# Page 15028 is working well
# Page 15029 is working well
# Page 15030 is working well
# Page 15031 is working well
# Page 15032 is working well
# Page 15033 is working well
# Page 15034 is working well
# Page 15035 is working well
# Page 15036 is working well
# Page 15037 is working well
# Page 15038 is working well
# Page 15039 is working well
# Page 15040 is working well
# Page 15041 is working well
# Page 15042 is working well
# Page 15043 is working well
# Page 15044 is working well
# Page 15045 is working well
# Page 15046 is working well
# Page 15047 is working well
# Page 15048 is working well
# Page 15049 is working well
# Page 15050 is working well
# Page 15051 is working well
# Page 15052 is working well
# Page 15053 is working well
# Page 15054 is working well
# Page 15055 is working well
# Page 15056 is working well
# Page 15057 is working well
# Page 15058 is working well
# Page 15059 is working well
# Page 15060 is working well
# Page 15061 is working well
# Page 15062 is working well
# Page 15063 is working well
# Page 15064 is working well
# Page 15065 is working well
# Page 15066 is working well
# Page 15067 is working well
# Page 15068 is working well
# Page 15069 is working well
# Page 15070 is working well
# Page 15071 is working well
# Page 15072 is working well
# Page 15073 is working well
# Page 15074 is working well
# Page 15075 is working well
# Page 15076 is working well
# Page 15077 is working well
# Page 15078 is working well
# Page 15079 is working well
# Page 15080 is working well
# Page 15081 is working well
# Page 15082 is working well
# Page 15083 is working well
# Page 15084 is working well
# Page 15085 is working well
# Page 15086 is working well
# Page 15087 is working well
# Page 15088 is working well
# Page 15089 is working well
# Page 15090 is working well
# Page 15091 is working well
# Page 15092 is working well
# Page 15093 is working well
# Page 15094 is working well
# Page 15095 is working well
# Page 15096 is working well
# Page 15097 is working well
# Page 15098 is working well
# Page 15099 is working well
# Page 15100 is working well
# Page 15101 is working well
# Page 15102 is working well
# Page 15103 is working well
# Page 15104 is working well
# Page 15105 is working well
# Page 15106 is working well
# Page 15107 is working well
# Page 15108 is working well
# Page 15109 is working well
# Page 15110 is working well
# Page 15111 is working well
# Page 15112 is working well
# Page 15113 is working well
# Page 15114 is working well
# Page 15115 is working well
# Page 15116 is working well
# Page 15117 is working well
# Page 15118 is working well
# Page 15119 is working well
# Page 15120 is working well
# Page 15121 is working well
# Page 15122 is working well
# Page 15123 is working well
# Page 15124 is working well
# Page 15125 is working well
# Page 15126 is working well
# Page 15127 is working well
# Page 15128 is working well
# Page 15129 is working well
# Page 15130 is working well
# Page 15131 is working well
# Page 15132 is working well
# Page 15133 is working well
# Page 15134 is working well
# Page 15135 is working well
# Page 15136 is working well
# Page 15137 is working well
# Page 15138 is working well
# Page 15139 is working well
# Page 15140 is working well
# Page 15141 is working well
# Page 15142 is working well
# Page 15143 is working well
# Page 15144 is working well
# Page 15145 is working well
# Page 15146 is working well
# Page 15147 is working well
# Page 15148 is working well
# Page 15149 is working well
# Page 15150 is working well
# Page 15151 is working well
# Page 15152 is working well
# Page 15153 is working well
# Page 15154 is working well
# Page 15155 is working well
# Page 15156 is working well
# Page 15157 is working well
# Page 15158 is working well
# Page 15159 is working well
# Page 15160 is working well
# Page 15161 is working well
# Page 15162 is working well
# Page 15163 is working well
# Page 15164 is working well
# Page 15165 is working well
# Page 15166 is working well
# Page 15167 is working well
# Page 15168 is working well
# Page 15169 is working well
# Page 15170 is working well
# Page 15171 is working well
# Page 15172 is working well
# Page 15173 is working well
# Page 15174 is working well
# Page 15175 is working well
# Page 15176 is working well
# Page 15177 is working well
# Page 15178 is working well
# Page 15179 is working well
# Page 15180 is working well
# Page 15181 is working well
# Page 15182 is working well
# Page 15183 is working well
# Page 15184 is working well
# Page 15185 is working well
# Page 15186 is working well
# Page 15187 is working well
# Page 15188 is working well
# Page 15189 is working well
# Page 15190 is working well
# Page 15191 is working well
# Page 15192 is working well
# Page 15193 is working well
# Page 15194 is working well
# Page 15195 is working well
# Page 15196 is working well
# Page 15197 is working well
# Page 15198 is working well
# Page 15199 is working well
# Page 15200 is working well
# Page 15201 is working well
# Page 15202 is working well
# Page 15203 is working well
# Page 15204 is working well
# Page 15205 is working well
# Page 15206 is working well
# Page 15207 is working well
# Page 15208 is working well
# Page 15209 is working well
# Page 15210 is working well
# Page 15211 is working well
# Page 15212 is working well
# Page 15213 is working well
# Page 15214 is working well
# Page 15215 is working well
# Page 15216 is working well
# Page 15217 is working well
# Page 15218 is working well
# Page 15219 is working well
# Page 15220 is working well
# Page 15221 is working well
# Page 15222 is working well
# Page 15223 is working well
# Page 15224 is working well
# Page 15225 is working well
# Page 15226 is working well
# Page 15227 is working well
# Page 15228 is working well
# Page 15229 is working well
# Page 15230 is working well
# Page 15231 is working well
# Page 15232 is working well
# Page 15233 is working well
# Page 15234 is working well
# Page 15235 is working well
# Page 15236 is working well
# Page 15237 is working well
# Page 15238 is working well
# Page 15239 is working well
# Page 15240 is working well
# Page 15241 is working well
# Page 15242 is working well
# Page 15243 is working well
# Page 15244 is working well
# Page 15245 is working well
# Page 15246 is working well
# Page 15247 is working well
# Page 15248 is working well
# Page 15249 is working well
# Page 15250 is working well
# Page 15251 is working well
# Page 15252 is working well
# Page 15253 is working well
# Page 15254 is working well
# Page 15255 is working well
# Page 15256 is working well
# Page 15257 is working well
# Page 15258 is working well
# Page 15259 is working well
# Page 15260 is working well
# Page 15261 is working well
# Page 15262 is working well
# Page 15263 is working well
# Page 15264 is working well
# Page 15265 is working well
# Page 15266 is working well
# Page 15267 is working well
# Page 15268 is working well
# Page 15269 is working well
# Page 15270 is working well
# Page 15271 is working well
# Page 15272 is working well
# Page 15273 is working well
# Page 15274 is working well
# Page 15275 is working well
# Page 15276 is working well
# Page 15277 is working well
# Page 15278 is working well
# Page 15279 is working well
# Page 15280 is working well
# Page 15281 is working well
# Page 15282 is working well
# Page 15283 is working well
# Page 15284 is working well
# Page 15285 is working well
# Page 15286 is working well
# Page 15287 is working well
# Page 15288 is working well
# Page 15289 is working well
# Page 15290 is working well
# Page 15291 is working well
# Page 15292 is working well
# Page 15293 is working well
# Page 15294 is working well
# Page 15295 is working well
# Page 15296 is working well
# Page 15297 is working well
# Page 15298 is working well
# Page 15299 is working well
# Page 15300 is working well
# Page 15301 is working well
# Page 15302 is working well
# Page 15303 is working well
# Page 15304 is working well
# Page 15305 is working well
# Page 15306 is working well
# Page 15307 is working well
# Page 15308 is working well
# Page 15309 is working well
# Page 15310 is working well
# Page 15311 is working well
# Page 15312 is working well
# Page 15313 is working well
# Page 15314 is working well
# Page 15315 is working well
# Page 15316 is working well
# Page 15317 is working well
# Page 15318 is working well
# Page 15319 is working well
# Page 15320 is working well
# Page 15321 is working well
# Page 15322 is working well
# Page 15323 is working well
# Page 15324 is working well
# Page 15325 is working well
# Page 15326 is working well
# Page 15327 is working well
# Page 15328 is working well
# Page 15329 is working well
# Page 15330 is working well
# Page 15331 is working well
# Page 15332 is working well
# Page 15333 is working well
# Page 15334 is working well
# Page 15335 is working well
# Page 15336 is working well
# Page 15337 is working well
# Page 15338 is working well
# Page 15339 is working well
# Page 15340 is working well
# Page 15341 is working well
# Page 15342 is working well
# Page 15343 is working well
# Page 15344 is working well
# Page 15345 is working well
# Page 15346 is working well
# Page 15347 is working well
# Page 15348 is working well
# Page 15349 is working well
# Page 15350 is working well
# Page 15351 is working well
# Page 15352 is working well
# Page 15353 is working well
# Page 15354 is working well
# Page 15355 is working well
# Page 15356 is working well
# Page 15357 is working well
# Page 15358 is working well
# Page 15359 is working well
# Page 15360 is working well
# Page 15361 is working well
# Page 15362 is working well
# Page 15363 is working well
# Page 15364 is working well
# Page 15365 is working well
# Page 15366 is working well
# Page 15367 is working well
# Page 15368 is working well
# Page 15369 is working well
# Page 15370 is working well
# Page 15371 is working well
# Page 15372 is working well
# Page 15373 is working well
# Page 15374 is working well
# Page 15375 is working well
# Page 15376 is working well
# Page 15377 is working well
# Page 15378 is working well
# Page 15379 is working well
# Page 15380 is working well
# Page 15381 is working well
# Page 15382 is working well
# Page 15383 is working well
# Page 15384 is working well
# Page 15385 is working well
# Page 15386 is working well
# Page 15387 is working well
# Page 15388 is working well
# Page 15389 is working well
# Page 15390 is working well
# Page 15391 is working well
# Page 15392 is working well
# Page 15393 is working well
# Page 15394 is working well
# Page 15395 is working well
# Page 15396 is working well
# Page 15397 is working well
# Page 15398 is working well
# Page 15399 is working well
# Page 15400 is working well
# Page 15401 is working well
# Page 15402 is working well
# Page 15403 is working well
# Page 15404 is working well
# Page 15405 is working well
# Page 15406 is working well
# Page 15407 is working well
# Page 15408 is working well
# Page 15409 is working well
# Page 15410 is working well
# Page 15411 is working well
# Page 15412 is working well
# Page 15413 is working well
# Page 15414 is working well
# Page 15415 is working well
# Page 15416 is working well
# Page 15417 is working well
# Page 15418 is working well
# Page 15419 is working well
# Page 15420 is working well
# Page 15421 is working well
# Page 15422 is working well
# Page 15423 is working well
# Page 15424 is working well
# Page 15425 is working well
# Page 15426 is working well
# Page 15427 is working well
# Page 15428 is working well
# Page 15429 is working well
# Page 15430 is working well
# Page 15431 is working well
# Page 15432 is working well
# Page 15433 is working well
# Page 15434 is working well
# Page 15435 is working well
# Page 15436 is working well
# Page 15437 is working well
# Page 15438 is working well
# Page 15439 is working well
# Page 15440 is working well
# Page 15441 is working well
# Page 15442 is working well
# Page 15443 is working well
# Page 15444 is working well
# Page 15445 is working well
# Page 15446 is working well
# Page 15447 is working well
# Page 15448 is working well
# Page 15449 is working well
# Page 15450 is working well
# Page 15451 is working well
# Page 15452 is working well
# Page 15453 is working well
# Page 15454 is working well
# Page 15455 is working well
# Page 15456 is working well
# Page 15457 is working well
# Page 15458 is working well
# Page 15459 is working well
# Page 15460 is working well
# Page 15461 is working well
# Page 15462 is working well
# Page 15463 is working well
# Page 15464 is working well
# Page 15465 is working well
# Page 15466 is working well
# Page 15467 is working well
# Page 15468 is working well
# Page 15469 is working well
# Page 15470 is working well
# Page 15471 is working well
# Page 15472 is working well
# Page 15473 is working well
# Page 15474 is working well
# Page 15475 is working well
# Page 15476 is working well
# Page 15477 is working well
# Page 15478 is working well
# Page 15479 is working well
# Page 15480 is working well
# Page 15481 is working well
# Page 15482 is working well
# Page 15483 is working well
# Page 15484 is working well
# Page 15485 is working well
# Page 15486 is working well
# Page 15487 is working well
# Page 15488 is working well
# Page 15489 is working well
# Page 15490 is working well
# Page 15491 is working well
# Page 15492 is working well
# Page 15493 is working well
# Page 15494 is working well
# Page 15495 is working well
# Page 15496 is working well
# Page 15497 is working well
# Page 15498 is working well
# Page 15499 is working well
# Page 15500 is working well
# Page 15501 is working well
# Page 15502 is working well
# Page 15503 is working well
# Page 15504 is working well
# Page 15505 is working well
# Page 15506 is working well
# Page 15507 is working well
# Page 15508 is working well
# Page 15509 is working well
# Page 15510 is working well
# Page 15511 is working well
# Page 15512 is working well
# Page 15513 is working well
# Page 15514 is working well
# Page 15515 is working well
# Page 15516 is working well
# Page 15517 is working well
# Page 15518 is working well
# Page 15519 is working well
# Page 15520 is working well
# Page 15521 is working well
# Page 15522 is working well
# Page 15523 is working well
# Page 15524 is working well
# Page 15525 is working well
# Page 15526 is working well
# Page 15527 is working well
# Page 15528 is working well
# Page 15529 is working well
# Page 15530 is working well
# Page 15531 is working well
# Page 15532 is working well
# Page 15533 is working well
# Page 15534 is working well
# Page 15535 is working well
# Page 15536 is working well
# Page 15537 is working well
# Page 15538 is working well
# Page 15539 is working well
# Page 15540 is working well
# Page 15541 is working well
# Page 15542 is working well
# Page 15543 is working well
# Page 15544 is working well
# Page 15545 is working well
# Page 15546 is working well
# Page 15547 is working well
# Page 15548 is working well
# Page 15549 is working well
# Page 15550 is working well
# Page 15551 is working well
# Page 15552 is working well
# Page 15553 is working well
# Page 15554 is working well
# Page 15555 is working well
# Page 15556 is working well
# Page 15557 is working well
# Page 15558 is working well
# Page 15559 is working well
# Page 15560 is working well
# Page 15561 is working well
# Page 15562 is working well
# Page 15563 is working well
# Page 15564 is working well
# Page 15565 is working well
# Page 15566 is working well
# Page 15567 is working well
# Page 15568 is working well
# Page 15569 is working well
# Page 15570 is working well
# Page 15571 is working well
# Page 15572 is working well
# Page 15573 is working well
# Page 15574 is working well
# Page 15575 is working well
# Page 15576 is working well
# Page 15577 is working well
# Page 15578 is working well
# Page 15579 is working well
# Page 15580 is working well
# Page 15581 is working well
# Page 15582 is working well
# Page 15583 is working well
# Page 15584 is working well
# Page 15585 is working well
# Page 15586 is working well
# Page 15587 is working well
# Page 15588 is working well
# Page 15589 is working well
# Page 15590 is working well
# Page 15591 is working well
# Page 15592 is working well
# Page 15593 is working well
# Page 15594 is working well
# Page 15595 is working well
# Page 15596 is working well
# Page 15597 is working well
# Page 15598 is working well
# Page 15599 is working well
# Page 15600 is working well
# Page 15601 is working well
# Page 15602 is working well
# Page 15603 is working well
# Page 15604 is working well
# Page 15605 is working well
# Page 15606 is working well
# Page 15607 is working well
# Page 15608 is working well
# Page 15609 is working well
# Page 15610 is working well
# Page 15611 is working well
# Page 15612 is working well
# Page 15613 is working well
# Page 15614 is working well
# Page 15615 is working well
# Page 15616 is working well
# Page 15617 is working well
# Page 15618 is working well
# Page 15619 is working well
# Page 15620 is working well
# Page 15621 is working well
# Page 15622 is working well
# Page 15623 is working well
# Page 15624 is working well
# Page 15625 is working well
# Page 15626 is working well
# Page 15627 is working well
# Page 15628 is working well
# Page 15629 is working well
# Page 15630 is working well
# Page 15631 is working well
# Page 15632 is working well
# Page 15633 is working well
# Page 15634 is working well
# Page 15635 is working well
# Page 15636 is working well
# Page 15637 is working well
# Page 15638 is working well
# Page 15639 is working well
# Page 15640 is working well
# Page 15641 is working well
# Page 15642 is working well
# Page 15643 is working well
# Page 15644 is working well
# Page 15645 is working well
# Page 15646 is working well
# Page 15647 is working well
# Page 15648 is working well
# Page 15649 is working well
# Page 15650 is working well
# Page 15651 is working well
# Page 15652 is working well
# Page 15653 is working well
# Page 15654 is working well
# Page 15655 is working well
# Page 15656 is working well
# Page 15657 is working well
# Page 15658 is working well
# Page 15659 is working well
# Page 15660 is working well
# Page 15661 is working well
# Page 15662 is working well
# Page 15663 is working well
# Page 15664 is working well
# Page 15665 is working well
# Page 15666 is working well
# Page 15667 is working well
# Page 15668 is working well
# Page 15669 is working well
# Page 15670 is working well
# Page 15671 is working well
# Page 15672 is working well
# Page 15673 is working well
# Page 15674 is working well
# Page 15675 is working well
# Page 15676 is working well
# Page 15677 is working well
# Page 15678 is working well
# Page 15679 is working well
# Page 15680 is working well
# Page 15681 is working well
# Page 15682 is working well
# Page 15683 is working well
# Page 15684 is working well
# Page 15685 is working well
# Page 15686 is working well
# Page 15687 is working well
# Page 15688 is working well
# Page 15689 is working well
# Page 15690 is working well
# Page 15691 is working well
# Page 15692 is working well
# Page 15693 is working well
# Page 15694 is working well
# Page 15695 is working well
# Page 15696 is working well
# Page 15697 is working well
# Page 15698 is working well
# Page 15699 is working well
# Page 15700 is working well
# Page 15701 is working well
# Page 15702 is working well
# Page 15703 is working well
# Page 15704 is working well
# Page 15705 is working well
# Page 15706 is working well
# Page 15707 is working well
# Page 15708 is working well
# Page 15709 is working well
# Page 15710 is working well
# Page 15711 is working well
# Page 15712 is working well
# Page 15713 is working well
# Page 15714 is working well
# Page 15715 is working well
# Page 15716 is working well
# Page 15717 is working well
# Page 15718 is working well
# Page 15719 is working well
# Page 15720 is working well
# Page 15721 is working well
# Page 15722 is working well
# Page 15723 is working well
# Page 15724 is working well
# Page 15725 is working well
# Page 15726 is working well
# Page 15727 is working well
# Page 15728 is working well
# Page 15729 is working well
# Page 15730 is working well
# Page 15731 is working well
# Page 15732 is working well
# Page 15733 is working well
# Page 15734 is working well
# Page 15735 is working well
# Page 15736 is working well
# Page 15737 is working well
# Page 15738 is working well
# Page 15739 is working well
# Page 15740 is working well
# Page 15741 is working well
# Page 15742 is working well
# Page 15743 is working well
# Page 15744 is working well
# Page 15745 is working well
# Page 15746 is working well
# Page 15747 is working well
# Page 15748 is working well
# Page 15749 is working well
# Page 15750 is working well
# Page 15751 is working well
# Page 15752 is working well
# Page 15753 is working well
# Page 15754 is working well
# Page 15755 is working well
# Page 15756 is working well
# Page 15757 is working well
# Page 15758 is working well
# Page 15759 is working well
# Page 15760 is working well
# Page 15761 is working well
# Page 15762 is working well
# Page 15763 is working well
# Page 15764 is working well
# Page 15765 is working well
# Page 15766 is working well
# Page 15767 is working well
# Page 15768 is working well
# Page 15769 is working well
# Page 15770 is working well
# Page 15771 is working well
# Page 15772 is working well
# Page 15773 is working well
# Page 15774 is working well
# Page 15775 is working well
# Page 15776 is working well
# Page 15777 is working well
# Page 15778 is working well
# Page 15779 is working well
# Page 15780 is working well
# Page 15781 is working well
# Page 15782 is working well
# Page 15783 is working well
# Page 15784 is working well
# Page 15785 is working well
# Page 15786 is working well
# Page 15787 is working well
# Page 15788 is working well
# Page 15789 is working well
# Page 15790 is working well
# Page 15791 is working well
# Page 15792 is working well
# Page 15793 is working well
# Page 15794 is working well
# Page 15795 is working well
# Page 15796 is working well
# Page 15797 is working well
# Page 15798 is working well
# Page 15799 is working well
# Page 15800 is working well
# Page 15801 is working well
# Page 15802 is working well
# Page 15803 is working well
# Page 15804 is working well
# Page 15805 is working well
# Page 15806 is working well
# Page 15807 is working well
# Page 15808 is working well
# Page 15809 is working well
# Page 15810 is working well
# Page 15811 is working well
# Page 15812 is working well
# Page 15813 is working well
# Page 15814 is working well
# Page 15815 is working well
# Page 15816 is working well
# Page 15817 is working well
# Page 15818 is working well
# Page 15819 is working well
# Page 15820 is working well
# Page 15821 is working well
# Page 15822 is working well
# Page 15823 is working well
# Page 15824 is working well
# Page 15825 is working well
# Page 15826 is working well
# Page 15827 is working well
# Page 15828 is working well
# Page 15829 is working well
# Page 15830 is working well
# Page 15831 is working well
# Page 15832 is working well
# Page 15833 is working well
# Page 15834 is working well
# Page 15835 is working well
# Page 15836 is working well
# Page 15837 is working well
# Page 15838 is working well
# Page 15839 is working well
# Page 15840 is working well
# Page 15841 is working well
# Page 15842 is working well
# Page 15843 is working well
# Page 15844 is working well
# Page 15845 is working well
# Page 15846 is working well
# Page 15847 is working well
# Page 15848 is working well
# Page 15849 is working well
# Page 15850 is working well
# Page 15851 is working well
# Page 15852 is working well
# Page 15853 is working well
# Page 15854 is working well
# Page 15855 is working well
# Page 15856 is working well
# Page 15857 is working well
# Page 15858 is working well
# Page 15859 is working well
# Page 15860 is working well
# Page 15861 is working well
# Page 15862 is working well
# Page 15863 is working well
# Page 15864 is working well
# Page 15865 is working well
# Page 15866 is working well
# Page 15867 is working well
# Page 15868 is working well
# Page 15869 is working well
# Page 15870 is working well
# Page 15871 is working well
# Page 15872 is working well
# Page 15873 is working well
# Page 15874 is working well
# Page 15875 is working well
# Page 15876 is working well
# Page 15877 is working well
# Page 15878 is working well
# Page 15879 is working well
# Page 15880 is working well
# Page 15881 is working well
# Page 15882 is working well
# Page 15883 is working well
# Page 15884 is working well
# Page 15885 is working well
# Page 15886 is working well
# Page 15887 is working well
# Page 15888 is working well
# Page 15889 is working well
# Page 15890 is working well
# Page 15891 is working well
# Page 15892 is working well
# Page 15893 is working well
# Page 15894 is working well
# Page 15895 is working well
# Page 15896 is working well
# Page 15897 is working well
# Page 15898 is working well
# Page 15899 is working well
# Page 15900 is working well
# Page 15901 is working well
# Page 15902 is working well
# Page 15903 is working well
# Page 15904 is working well
# Page 15905 is working well
# Page 15906 is working well
# Page 15907 is working well
# Page 15908 is working well
# Page 15909 is working well
# Page 15910 is working well
# Page 15911 is working well
# Page 15912 is working well
# Page 15913 is working well
# Page 15914 is working well
# Page 15915 is working well
# Page 15916 is working well
# Page 15917 is working well
# Page 15918 is working well
# Page 15919 is working well
# Page 15920 is working well
# Page 15921 is working well
# Page 15922 is working well
# Page 15923 is working well
# Page 15924 is working well
# Page 15925 is working well
# Page 15926 is working well
# Page 15927 is working well
# Page 15928 is working well
# Page 15929 is working well
# Page 15930 is working well
# Page 15931 is working well
# Page 15932 is working well
# Page 15933 is working well
# Page 15934 is working well
# Page 15935 is working well
# Page 15936 is working well
# Page 15937 is working well
# Page 15938 is working well
# Page 15939 is working well
# Page 15940 is working well
# Page 15941 is working well
# Page 15942 is working well
# Page 15943 is working well
# Page 15944 is working well
# Page 15945 is working well
# Page 15946 is working well
# Page 15947 is working well
# Page 15948 is working well
# Page 15949 is working well
# Page 15950 is working well
# Page 15951 is working well
# Page 15952 is working well
# Page 15953 is working well
# Page 15954 is working well
# Page 15955 is working well
# Page 15956 is working well
# Page 15957 is working well
# Page 15958 is working well
# Page 15959 is working well
# Page 15960 is working well
# Page 15961 is working well
# Page 15962 is working well
# Page 15963 is working well
# Page 15964 is working well
# Page 15965 is working well
# Page 15966 is working well
# Page 15967 is working well
# Page 15968 is working well
# Page 15969 is working well
# Page 15970 is working well
# Page 15971 is working well
# Page 15972 is working well
# Page 15973 is working well
# Page 15974 is working well
# Page 15975 is working well
# Page 15976 is working well
# Page 15977 is working well
# Page 15978 is working well
# Page 15979 is working well
# Page 15980 is working well
# Page 15981 is working well
# Page 15982 is working well
# Page 15983 is working well
# Page 15984 is working well
# Page 15985 is working well
# Page 15986 is working well
# Page 15987 is working well
# Page 15988 is working well
# Page 15989 is working well
# Page 15990 is working well
# Page 15991 is working well
# Page 15992 is working well
# Page 15993 is working well
# Page 15994 is working well
# Page 15995 is working well
# Page 15996 is working well
# Page 15997 is working well
# Page 15998 is working well
# Page 15999 is working well
# Page 16000 is working well
# Page 16001 is working well
# Page 16002 is working well
# Page 16003 is working well
# Page 16004 is working well
# Page 16005 is working well
# Page 16006 is working well
# Page 16007 is working well
# Page 16008 is working well
# Page 16009 is working well
# Page 16010 is working well
# Page 16011 is working well
# Page 16012 is working well
# Page 16013 is working well
# Page 16014 is working well
# Page 16015 is working well
# Page 16016 is working well
# Page 16017 is working well
# Page 16018 is working well
# Page 16019 is working well
# Page 16020 is working well
# Page 16021 is working well
# Page 16022 is working well
# Page 16023 is working well
# Page 16024 is working well
# Page 16025 is working well
# Page 16026 is working well
# Page 16027 is working well
# Page 16028 is working well
# Page 16029 is working well
# Page 16030 is working well
# Page 16031 is working well
# Page 16032 is working well
# Page 16033 is working well
# Page 16034 is working well
# Page 16035 is working well
# Page 16036 is working well
# Page 16037 is working well
# Page 16038 is working well
# Page 16039 is working well
# Page 16040 is working well
# Page 16041 is working well
# Page 16042 is working well
# Page 16043 is working well
# Page 16044 is working well
# Page 16045 is working well
# Page 16046 is working well
# Page 16047 is working well
# Page 16048 is working well
# Page 16049 is working well
# Page 16050 is working well
# Page 16051 is working well
# Page 16052 is working well
# Page 16053 is working well
# Page 16054 is working well
# Page 16055 is working well
# Page 16056 is working well
# Page 16057 is working well
# Page 16058 is working well
# Page 16059 is working well
# Page 16060 is working well
# Page 16061 is working well
# Page 16062 is working well
# Page 16063 is working well
# Page 16064 is working well
# Page 16065 is working well
# Page 16066 is working well
# Page 16067 is working well
# Page 16068 is working well
# Page 16069 is working well
# Page 16070 is working well
# Page 16071 is working well
# Page 16072 is working well
# Page 16073 is working well
# Page 16074 is working well
# Page 16075 is working well
# Page 16076 is working well
# Page 16077 is working well
# Page 16078 is working well
# Page 16079 is working well
# Page 16080 is working well
# Page 16081 is working well
# Page 16082 is working well
# Page 16083 is working well
# Page 16084 is working well
# Page 16085 is working well
# Page 16086 is working well
# Page 16087 is working well
# Page 16088 is working well
# Page 16089 is working well
# Page 16090 is working well
# Page 16091 is working well
# Page 16092 is working well
# Page 16093 is working well
# Page 16094 is working well
# Page 16095 is working well
# Page 16096 is working well
# Page 16097 is working well
# Page 16098 is working well
# Page 16099 is working well
# Page 16100 is working well
# Page 16101 is working well
# Page 16102 is working well
# Page 16103 is working well
# Page 16104 is working well
# Page 16519 is working well
# Page 16520 is working well
# Page 16521 is working well
# Page 16522 is working well
# Page 16523 is working well
# Page 16524 is working well
# Page 16525 is working well
# Page 16526 is working well
# Page 16527 is working well
# Page 16528 is working well
# Page 16529 is working well
# Page 16530 is working well
# Page 16531 is working well
# Page 16532 is working well
# Page 16533 is working well
# Page 16534 is working well
# Page 16535 is working well
# Page 16536 is working well
# Page 16537 is working well
# Page 16538 is working well
# Page 16539 is working well
# Page 16540 is working well
# Page 16541 is working well
# Page 16542 is working well
# Page 16543 is working well
# Page 16544 is working well
# Page 16545 is working well
# Page 16546 is working well
# Page 16547 is working well
# Page 16548 is working well
# Page 16549 is working well
# Page 16550 is working well
# Page 16551 is working well
# Page 16552 is working well
# Page 16553 is working well
# Page 16554 is working well
# Page 16555 is working well
# Page 16556 is working well
# Page 16557 is working well
# Page 16558 is working well
# Page 16559 is working well
# Page 16560 is working well
# Page 16561 is working well
# Page 16562 is working well
# Page 16563 is working well
# Page 16564 is working well
# Page 16565 is working well
# Page 16566 is working well
# Page 16567 is working well
# Page 16568 is working well
# Page 16569 is working well
# Page 16570 is working well
# Page 16571 is working well
# Page 16572 is working well
# Page 16573 is working well
# Page 16574 is working well
# Page 16575 is working well
# Page 16576 is working well
# Page 16577 is working well
# Page 16578 is working well
# Page 16579 is working well
# Page 16580 is working well
# Page 16581 is working well
# Page 16582 is working well
# Page 16583 is working well
# Page 16584 is working well
# Page 16585 is working well
# Page 16586 is working well
# Page 16587 is working well
# Page 16588 is working well
# Page 16589 is working well
# Page 16590 is working well

# %%
len(flats_dict)
# Out:
# 1590

# %%
df_flats = pd.DataFrame(flats_dict).T

# %%
df_flats.to_csv('flats_add.csv')

# %%
def check(l):
    
    flat_dict = {}
    
    # Это будет номер квартиры
    N = 0

    # Соберем все, что написано выше, вместе
    flat_page = requests.get(l[0])
    flat_page = flat_page.text
    flat_page = BeautifulSoup(flat_page, 'lxml')
    inf_table = flat_page.findAll('table', class_ = 'object_descr_tab')
    inf_table = inf_table[0]
    inner_table = inf_table.findAll('table', class_ = 'object_descr_props')
    inner_table = inner_table[0]

    house_coords = getCoords(flat_page)

    flat_dict[N] = {
            'Lat': house_coords[0],
            'Lon': house_coords[1],
            'District': l[1],
            'Small_district': small_dist_grabber(flat_page),
            'Rooms': room_grabber(inf_table),
            'Price': price_grabber(inf_table)[0],
            'Price_duplicate': price_grabber(inf_table)[1],
            'Totsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['totsp'],
            'Livesp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['kitsp'],
            'Kitsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['livesp'],
            'Rem': rem_grabber(inner_table),
            'Dist': dist_grabber(house_coords),
            'Stname': metro(inf_table)['stname'],
            'Metrdist': metro(inf_table)['metrdist'],
            'Walk': metro(inf_table)['walk'],
            'Brick': brick_grabber(flat_page),
            'Tel': tel_grabber(inner_table),
            'Bal': bal_grabber(inner_table),
            'Floor': floor_grabber(inner_table)['floor'],
            'Nfloors': floor_grabber(inner_table)['n_floor'],
            'New': new_grabber(inner_table),
            'Link': l[0]
        }
    
    return(flat_dict)
