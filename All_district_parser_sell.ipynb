# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ##### Теперь соберем квартиры со всех районов:

# %% [markdown]
# Ссылки на районы проще собрать вручную. Работающие функции просто скопируем из notebook с одним районом (иначе тот notebook станет очень громоздким). Все, что нужно поменять - это процесс сбора ссылок.

# %%
district_cao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=13&district%5B1%5D=14&district%5B2%5D=15&district%5B3%5D=16&district%5B4%5D=17&district%5B5%5D=18&district%5B6%5D=19&district%5B7%5D=20&district%5B8%5D=21&district%5B9%5D=22&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_sao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=23&district%5B1%5D=24&district%5B10%5D=33&district%5B11%5D=34&district%5B12%5D=35&district%5B13%5D=36&district%5B14%5D=37&district%5B15%5D=38&district%5B2%5D=25&district%5B3%5D=26&district%5B4%5D=27&district%5B5%5D=28&district%5B6%5D=29&district%5B7%5D=30&district%5B8%5D=31&district%5B9%5D=32&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_svao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=39&district%5B1%5D=40&district%5B10%5D=49&district%5B11%5D=50&district%5B12%5D=51&district%5B13%5D=52&district%5B14%5D=53&district%5B15%5D=54&district%5B16%5D=55&district%5B2%5D=41&district%5B3%5D=42&district%5B4%5D=43&district%5B5%5D=44&district%5B6%5D=45&district%5B7%5D=46&district%5B8%5D=47&district%5B9%5D=48&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_vao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=56&district%5B1%5D=57&district%5B10%5D=66&district%5B11%5D=67&district%5B12%5D=68&district%5B13%5D=69&district%5B14%5D=70&district%5B15%5D=71&district%5B2%5D=58&district%5B3%5D=59&district%5B4%5D=60&district%5B5%5D=61&district%5B6%5D=62&district%5B7%5D=63&district%5B8%5D=64&district%5B9%5D=65&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_uvao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=72&district%5B1%5D=73&district%5B10%5D=82&district%5B11%5D=83&district%5B2%5D=74&district%5B3%5D=75&district%5B4%5D=76&district%5B5%5D=77&district%5B6%5D=78&district%5B7%5D=79&district%5B8%5D=80&district%5B9%5D=81&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_uao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=84&district%5B1%5D=85&district%5B10%5D=94&district%5B11%5D=95&district%5B12%5D=96&district%5B13%5D=97&district%5B14%5D=98&district%5B15%5D=99&district%5B2%5D=86&district%5B3%5D=87&district%5B4%5D=88&district%5B5%5D=89&district%5B6%5D=90&district%5B7%5D=91&district%5B8%5D=92&district%5B9%5D=93&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_uzao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=100&district%5B1%5D=101&district%5B10%5D=110&district%5B11%5D=111&district%5B2%5D=102&district%5B3%5D=103&district%5B4%5D=104&district%5B5%5D=105&district%5B6%5D=106&district%5B7%5D=107&district%5B8%5D=108&district%5B9%5D=109&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_zao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=112&district%5B1%5D=113&district%5B10%5D=122&district%5B11%5D=123&district%5B12%5D=124&district%5B13%5D=348&district%5B14%5D=349&district%5B15%5D=350&district%5B2%5D=114&district%5B3%5D=115&district%5B4%5D=116&district%5B5%5D=117&district%5B6%5D=118&district%5B7%5D=119&district%5B8%5D=120&district%5B9%5D=121&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_szao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=125&district%5B1%5D=126&district%5B2%5D=127&district%5B3%5D=128&district%5B4%5D=129&district%5B5%5D=130&district%5B6%5D=131&district%5B7%5D=132&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_nao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=327&district%5B1%5D=328&district%5B10%5D=337&district%5B2%5D=329&district%5B3%5D=330&district%5B4%5D=331&district%5B5%5D=332&district%5B6%5D=333&district%5B7%5D=334&district%5B8%5D=335&district%5B9%5D=336&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_tao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=338&district%5B1%5D=339&district%5B2%5D=340&district%5B3%5D=341&district%5B4%5D=342&district%5B5%5D=343&district%5B6%5D=344&district%5B7%5D=345&district%5B8%5D=346&district%5B9%5D=347&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %%
district_zelao = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=152&district%5B1%5D=153&district%5B2%5D=154&district%5B3%5D=355&district%5B4%5D=356&district%5B5%5D=357&district%5B6%5D=358&engine_version=2&offer_type=flat&p={}&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1'

# %% [markdown]
# Создадим список с нашими районы, чтобы потом ходить по нему и из каждого раоны доставать ссылки на квартиры.

# %%
district = [district_cao, district_sao, district_svao, district_vao, district_uvao, district_uao, district_uzao,
            district_zao, district_szao, district_nao, district_tao, district_zelao]

# %% [markdown]
# ### Процесс сбора сылок

# %% [markdown]
# Уже готовая функция для сбора квартир с одной страницы.

# %%
# d отвечает за район - этот параметр будет нужен для сбора по районам
def page_grabber(page, d=0):
    flats_links = [] # список с ссылками с одной страницы поиска
    p = len(page)
    for i in range(p):
        flats_links.append((page[i].attrs['href'], d)) # один элемент - ссылка (то есть атрибут href тега div)
    return(flats_links)

# %% [markdown]
# Завернем процесс сбора квартир с одного района в функцию.

# %%
def district_page_grabber(district, j=0):
    
    links = [] # Список, который заполним всеми квартирами (только те, что размещены внутри самомго сайта)

    for i in range(1,31):
        # Получаем нужную страницу
        search_page = requests.get(district.format(i))
        search_page = search_page.text
        search_page = BeautifulSoup(search_page, 'lxml')

        # Внутри нужной страницы добираемся до таблицы с квартирами
        flats = search_page.html.body.findAll('div', id='content')
        flats = flats[0].findAll('div', attrs = {'class':'serp-list'})

        # В этой переменной будет лежать нужный кусок страницы (в каждой итерации новая страница)
        flats_cian = flats[0].findAll('div',\
                  attrs = {'ng-class':"{'serp-item_removed': offer.remove.state, 'serp-item_popup-opened': isPopupOpen}"})

        # Берем ссылки с текущей страницы и кладем в наш общий список ссылок
        links = links + page_grabber(flats_cian, d=j)

        # Каждую итерацию проверяем, что все нормально работает 
        print('Page_{}_ok_Iter={}'.format(i,j))
        
    return(links)

# %% [markdown]
# Теперь соберем ссылки с кадого района

# %%
l = len(district)
j = 0

links = []

for dist in range(l):
    
    links = links + district_page_grabber(district[dist], j=j)
    
    j += 1
# Out:
# Page_1_ok_Iter=0
# Page_2_ok_Iter=0
# Page_3_ok_Iter=0
# Page_4_ok_Iter=0
# Page_5_ok_Iter=0
# Page_6_ok_Iter=0
# Page_7_ok_Iter=0
# Page_8_ok_Iter=0
# Page_9_ok_Iter=0
# Page_10_ok_Iter=0
# Page_11_ok_Iter=0
# Page_12_ok_Iter=0
# Page_13_ok_Iter=0
# Page_14_ok_Iter=0
# Page_15_ok_Iter=0
# Page_16_ok_Iter=0
# Page_17_ok_Iter=0
# Page_18_ok_Iter=0
# Page_19_ok_Iter=0
# Page_20_ok_Iter=0
# Page_21_ok_Iter=0
# Page_22_ok_Iter=0
# Page_23_ok_Iter=0
# Page_24_ok_Iter=0
# Page_25_ok_Iter=0
# Page_26_ok_Iter=0
# Page_27_ok_Iter=0
# Page_28_ok_Iter=0
# Page_29_ok_Iter=0
# Page_30_ok_Iter=0
# Page_1_ok_Iter=1
# Page_2_ok_Iter=1
# Page_3_ok_Iter=1
# Page_4_ok_Iter=1
# Page_5_ok_Iter=1
# Page_6_ok_Iter=1
# Page_7_ok_Iter=1
# Page_8_ok_Iter=1
# Page_9_ok_Iter=1
# Page_10_ok_Iter=1
# Page_11_ok_Iter=1
# Page_12_ok_Iter=1
# Page_13_ok_Iter=1
# Page_14_ok_Iter=1
# Page_15_ok_Iter=1
# Page_16_ok_Iter=1
# Page_17_ok_Iter=1
# Page_18_ok_Iter=1
# Page_19_ok_Iter=1
# Page_20_ok_Iter=1
# Page_21_ok_Iter=1
# Page_22_ok_Iter=1
# Page_23_ok_Iter=1
# Page_24_ok_Iter=1
# Page_25_ok_Iter=1
# Page_26_ok_Iter=1
# Page_27_ok_Iter=1
# Page_28_ok_Iter=1
# Page_29_ok_Iter=1
# Page_30_ok_Iter=1
# Page_1_ok_Iter=2
# Page_2_ok_Iter=2
# Page_3_ok_Iter=2
# Page_4_ok_Iter=2
# Page_5_ok_Iter=2
# Page_6_ok_Iter=2
# Page_7_ok_Iter=2
# Page_8_ok_Iter=2
# Page_9_ok_Iter=2
# Page_10_ok_Iter=2
# Page_11_ok_Iter=2
# Page_12_ok_Iter=2
# Page_13_ok_Iter=2
# Page_14_ok_Iter=2
# Page_15_ok_Iter=2
# Page_16_ok_Iter=2
# Page_17_ok_Iter=2
# Page_18_ok_Iter=2
# Page_19_ok_Iter=2
# Page_20_ok_Iter=2
# Page_21_ok_Iter=2
# Page_22_ok_Iter=2
# Page_23_ok_Iter=2
# Page_24_ok_Iter=2
# Page_25_ok_Iter=2
# Page_26_ok_Iter=2
# Page_27_ok_Iter=2
# Page_28_ok_Iter=2
# Page_29_ok_Iter=2
# Page_30_ok_Iter=2
# Page_1_ok_Iter=3
# Page_2_ok_Iter=3
# Page_3_ok_Iter=3
# Page_4_ok_Iter=3
# Page_5_ok_Iter=3
# Page_6_ok_Iter=3
# Page_7_ok_Iter=3
# Page_8_ok_Iter=3
# Page_9_ok_Iter=3
# Page_10_ok_Iter=3
# Page_11_ok_Iter=3
# Page_12_ok_Iter=3
# Page_13_ok_Iter=3
# Page_14_ok_Iter=3
# Page_15_ok_Iter=3
# Page_16_ok_Iter=3
# Page_17_ok_Iter=3
# Page_18_ok_Iter=3
# Page_19_ok_Iter=3
# Page_20_ok_Iter=3
# Page_21_ok_Iter=3
# Page_22_ok_Iter=3
# Page_23_ok_Iter=3
# Page_24_ok_Iter=3
# Page_25_ok_Iter=3
# Page_26_ok_Iter=3
# Page_27_ok_Iter=3
# Page_28_ok_Iter=3
# Page_29_ok_Iter=3
# Page_30_ok_Iter=3
# Page_1_ok_Iter=4
# Page_2_ok_Iter=4
# Page_3_ok_Iter=4
# Page_4_ok_Iter=4
# Page_5_ok_Iter=4
# Page_6_ok_Iter=4
# Page_7_ok_Iter=4
# Page_8_ok_Iter=4
# Page_9_ok_Iter=4
# Page_10_ok_Iter=4
# Page_11_ok_Iter=4
# Page_12_ok_Iter=4
# Page_13_ok_Iter=4
# Page_14_ok_Iter=4
# Page_15_ok_Iter=4
# Page_16_ok_Iter=4
# Page_17_ok_Iter=4
# Page_18_ok_Iter=4
# Page_19_ok_Iter=4
# Page_20_ok_Iter=4
# Page_21_ok_Iter=4
# Page_22_ok_Iter=4
# Page_23_ok_Iter=4
# Page_24_ok_Iter=4
# Page_25_ok_Iter=4
# Page_26_ok_Iter=4
# Page_27_ok_Iter=4
# Page_28_ok_Iter=4
# Page_29_ok_Iter=4
# Page_30_ok_Iter=4
# Page_1_ok_Iter=5
# Page_2_ok_Iter=5
# Page_3_ok_Iter=5
# Page_4_ok_Iter=5
# Page_5_ok_Iter=5
# Page_6_ok_Iter=5
# Page_7_ok_Iter=5
# Page_8_ok_Iter=5
# Page_9_ok_Iter=5
# Page_10_ok_Iter=5
# Page_11_ok_Iter=5
# Page_12_ok_Iter=5
# Page_13_ok_Iter=5
# Page_14_ok_Iter=5
# Page_15_ok_Iter=5
# Page_16_ok_Iter=5
# Page_17_ok_Iter=5
# Page_18_ok_Iter=5
# Page_19_ok_Iter=5
# Page_20_ok_Iter=5
# Page_21_ok_Iter=5
# Page_22_ok_Iter=5
# Page_23_ok_Iter=5
# Page_24_ok_Iter=5
# Page_25_ok_Iter=5
# Page_26_ok_Iter=5
# Page_27_ok_Iter=5
# Page_28_ok_Iter=5
# Page_29_ok_Iter=5
# Page_30_ok_Iter=5
# Page_1_ok_Iter=6
# Page_2_ok_Iter=6
# Page_3_ok_Iter=6
# Page_4_ok_Iter=6
# Page_5_ok_Iter=6
# Page_6_ok_Iter=6
# Page_7_ok_Iter=6
# Page_8_ok_Iter=6
# Page_9_ok_Iter=6
# Page_10_ok_Iter=6
# Page_11_ok_Iter=6
# Page_12_ok_Iter=6
# Page_13_ok_Iter=6
# Page_14_ok_Iter=6
# Page_15_ok_Iter=6
# Page_16_ok_Iter=6
# Page_17_ok_Iter=6
# Page_18_ok_Iter=6
# Page_19_ok_Iter=6
# Page_20_ok_Iter=6
# Page_21_ok_Iter=6
# Page_22_ok_Iter=6
# Page_23_ok_Iter=6
# Page_24_ok_Iter=6
# Page_25_ok_Iter=6
# Page_26_ok_Iter=6
# Page_27_ok_Iter=6
# Page_28_ok_Iter=6
# Page_29_ok_Iter=6
# Page_30_ok_Iter=6
# Page_1_ok_Iter=7
# Page_2_ok_Iter=7
# Page_3_ok_Iter=7
# Page_4_ok_Iter=7
# Page_5_ok_Iter=7
# Page_6_ok_Iter=7
# Page_7_ok_Iter=7
# Page_8_ok_Iter=7
# Page_9_ok_Iter=7
# Page_10_ok_Iter=7
# Page_11_ok_Iter=7
# Page_12_ok_Iter=7
# Page_13_ok_Iter=7
# Page_14_ok_Iter=7
# Page_15_ok_Iter=7
# Page_16_ok_Iter=7
# Page_17_ok_Iter=7
# Page_18_ok_Iter=7
# Page_19_ok_Iter=7
# Page_20_ok_Iter=7
# Page_21_ok_Iter=7
# Page_22_ok_Iter=7
# Page_23_ok_Iter=7
# Page_24_ok_Iter=7
# Page_25_ok_Iter=7
# Page_26_ok_Iter=7
# Page_27_ok_Iter=7
# Page_28_ok_Iter=7
# Page_29_ok_Iter=7
# Page_30_ok_Iter=7
# Page_1_ok_Iter=8
# Page_2_ok_Iter=8
# Page_3_ok_Iter=8
# Page_4_ok_Iter=8
# Page_5_ok_Iter=8
# Page_6_ok_Iter=8
# Page_7_ok_Iter=8
# Page_8_ok_Iter=8
# Page_9_ok_Iter=8
# Page_10_ok_Iter=8
# Page_11_ok_Iter=8
# Page_12_ok_Iter=8
# Page_13_ok_Iter=8
# Page_14_ok_Iter=8
# Page_15_ok_Iter=8
# Page_16_ok_Iter=8
# Page_17_ok_Iter=8
# Page_18_ok_Iter=8
# Page_19_ok_Iter=8
# Page_20_ok_Iter=8
# Page_21_ok_Iter=8
# Page_22_ok_Iter=8
# Page_23_ok_Iter=8
# Page_24_ok_Iter=8
# Page_25_ok_Iter=8
# Page_26_ok_Iter=8
# Page_27_ok_Iter=8
# Page_28_ok_Iter=8
# Page_29_ok_Iter=8
# Page_30_ok_Iter=8
# Page_1_ok_Iter=9
# Page_2_ok_Iter=9
# Page_3_ok_Iter=9
# Page_4_ok_Iter=9
# Page_5_ok_Iter=9
# Page_6_ok_Iter=9
# Page_7_ok_Iter=9
# Page_8_ok_Iter=9
# Page_9_ok_Iter=9
# Page_10_ok_Iter=9
# Page_11_ok_Iter=9
# Page_12_ok_Iter=9
# Page_13_ok_Iter=9
# Page_14_ok_Iter=9
# Page_15_ok_Iter=9
# Page_16_ok_Iter=9
# Page_17_ok_Iter=9
# Page_18_ok_Iter=9
# Page_19_ok_Iter=9
# Page_20_ok_Iter=9
# Page_21_ok_Iter=9
# Page_22_ok_Iter=9
# Page_23_ok_Iter=9
# Page_24_ok_Iter=9
# Page_25_ok_Iter=9
# Page_26_ok_Iter=9
# Page_27_ok_Iter=9
# Page_28_ok_Iter=9
# Page_29_ok_Iter=9
# Page_30_ok_Iter=9
# Page_1_ok_Iter=10
# Page_2_ok_Iter=10
# Page_3_ok_Iter=10
# Page_4_ok_Iter=10
# Page_5_ok_Iter=10
# Page_6_ok_Iter=10
# Page_7_ok_Iter=10
# Page_8_ok_Iter=10
# Page_9_ok_Iter=10
# Page_10_ok_Iter=10
# Page_11_ok_Iter=10
# Page_12_ok_Iter=10
# Page_13_ok_Iter=10
# Page_14_ok_Iter=10
# Page_15_ok_Iter=10
# Page_16_ok_Iter=10
# Page_17_ok_Iter=10
# Page_18_ok_Iter=10
# Page_19_ok_Iter=10
# Page_20_ok_Iter=10
# Page_21_ok_Iter=10
# Page_22_ok_Iter=10
# Page_23_ok_Iter=10
# Page_24_ok_Iter=10
# Page_25_ok_Iter=10
# Page_26_ok_Iter=10
# Page_27_ok_Iter=10
# Page_28_ok_Iter=10
# Page_29_ok_Iter=10
# Page_30_ok_Iter=10
# Page_1_ok_Iter=11
# Page_2_ok_Iter=11
# Page_3_ok_Iter=11
# Page_4_ok_Iter=11
# Page_5_ok_Iter=11
# Page_6_ok_Iter=11
# Page_7_ok_Iter=11
# Page_8_ok_Iter=11
# Page_9_ok_Iter=11
# Page_10_ok_Iter=11
# Page_11_ok_Iter=11
# Page_12_ok_Iter=11
# Page_13_ok_Iter=11
# Page_14_ok_Iter=11
# Page_15_ok_Iter=11
# Page_16_ok_Iter=11
# Page_17_ok_Iter=11
# Page_18_ok_Iter=11
# Page_19_ok_Iter=11
# Page_20_ok_Iter=11
# Page_21_ok_Iter=11
# Page_22_ok_Iter=11
# Page_23_ok_Iter=11
# Page_24_ok_Iter=11
# Page_25_ok_Iter=11
# Page_26_ok_Iter=11
# Page_27_ok_Iter=11
# Page_28_ok_Iter=11
# Page_29_ok_Iter=11
# Page_30_ok_Iter=11

# %% [markdown]
# И выкинем из нашего списка дубликаты:

# %%
links = list(set(links))

# %% [markdown]
# На всякий случай запишем все собранные ссфлки в файл

# %%
with open('links.txt', 'a') as f:
    for i in range(len(links)):
        f.write(links[i][0] + ' dist=' + str(links[i][1]) + '\n')

# %%
links[:10]
# Out:
# [('http://www.cian.ru/sale/flat/148936137/', 10),
#  ('http://www.cian.ru/sale/flat/2462671/', 1),
#  ('http://www.cian.ru/sale/flat/43992990/', 1),
#  ('http://www.cian.ru/sale/flat/151019032/', 4),
#  ('http://www.cian.ru/sale/flat/151011793/', 6),
#  ('http://www.cian.ru/sale/flat/149607622/', 3),
#  ('http://www.cian.ru/sale/flat/150724229/', 10),
#  ('http://www.cian.ru/sale/flat/151162089/', 2),
#  ('http://www.cian.ru/sale/flat/150494770/', 6),
#  ('http://www.cian.ru/sale/flat/150967159/', 6)]

# %%
#links = []

# %%
#with open('sell_result/links.txt') as f:
#    for line in f:
#        line = (re.findall(r'.+ dist', line)[0][:-5], \
#               int(re.findall(r'dist=\d+', line)[0][5:]))
#        links.append(line)

# %%
len(links)
# Out:
# 8982

# %% [markdown]
# ### Процесс сбора квартир

# %% [markdown]
# #### Нужные функции

# %% [markdown]
# Число комнат

# %%
def room_grabber(table):
    room = table.findAll('div', class_='object_descr_title')
    try:
        room = re.findall(r'.?-комн. кв.' ,str(room[0]))[0]
    except:
        if re.findall(r'многокомн' ,str(room[0]))[0] == 'многокомн':
            room = [6]
    return(int(room[0]))

# %% [markdown]
# ---

# %% [markdown]
# Цена

# %%
def price_grabber(table):
    '''
    Будем возвращать цену списком. Судя по всему ЦИАН предоставил нам скрытый тег, в котором лежит цена в удобном для нас
    виде - на всякий случай будем собирать цену в двух вариантах (можно будет проверить + если один вариант отпал - другой будет доступен).
    В качестве нулевых значений возьмем NaN
    '''
    price = table.findAll('div', class_='object_descr_price_box')
    
    p1 = np.nan
    p2 = np.nan
    
    try:
        p1 = price[0].findAll('div')[0].string.strip()
        p1 = int(p1[:-5].replace(' ', ''))
    except:
        pass
    
    try:
        p2 = price[0].findAll('div')[1].string.strip()
        p2 = float(p2.replace(',', '.'))
    except:
        pass
    
    return([p1,p2])

# %% [markdown]
# ---

# %% [markdown]
# Расстояние до метро в минутах + Walk

# %%
def metro(table):
    try:
        # Нужный кусок html
        metro = table.findAll('div', class_='object_descr_metro')
        metro_name = metro[0].findAll('a', class_='object_item_metro_name')[0]
        metro = metro[0].findAll('span', class_='object_item_metro_comment')[0].string
        
        # Название станции
        name = metro_name.string[:-1]
        
        # Минуты
        metrdist = int(re.findall(r'\d+', metro)[0])

        # Walk
        walk = metro.replace(' ', '')
        walk = walk.replace('\n', '')
        walk = re.findall(r'мин\..+', walk)[0][4:]
        if walk == 'пешком':
            walk = 1
        elif walk == []:
            walk = np.nan
        else:
            walk = 0
    except:
        metrdist = np.nan
        walk = np.nan
        name = np.nan
        
    return({'metrdist': metrdist, 'walk': walk, 'stname': name})

# %% [markdown]
# ---

# %% [markdown]
# Материал стен: кирпичный/монолит/жб

# %%
def brick_grabber(flat_page):
    
    # Ищем на странице нужный кусок html кода
    house_table = flat_page.findAll('div', class_='offer_container object_descr cleared')
    house_table = house_table[0].findAll('div', class_='bti__inner')
    
    # Проверка на случай, если искомая секция вобще отсутствует на странице данной квартиры
    if house_table == []:
        brick = np.nan
    else:
        # Углубляемся в нужный кусок html кода
        first_table = house_table[0].findAll('tbody')[0]
        first_table_tr = first_table.findAll('tr') # Собрали все tr, то есть все секции первой малой таблицы

        #Ищем нужный th с информацией о материале
        for i in range(1,len(first_table_tr)):
            try:
                brick_str = re.findall(r'Материалы стен', str(first_table_tr[i].th))[0]
                if brick_str == 'Материалы стен':
                    # Ищем один из нужных нам флажков - кирпич, монолит или варианты ж/б
                    brick = re.findall(r'кирпич|монолит|ж??б|желез.+бетон', str(first_table_tr[i].td))
            except:
                pass

        # Проверяем результат регулярного выражения
        if len(brick) == 0:
            brick = 0
        else:
            brick = 1
        
    return(brick)

# %% [markdown]
# ---

# %% [markdown]
# Расстояние от центра в км.

# %%
def getCoords(flat_page):
    coords = flat_page.find('div', attrs={'class':'map_info_button_extend'}).contents[1]
    coords = re.split('&amp|center=|%2C', str(coords))
    coords_list = []
    for item in coords:
        if item[0].isdigit():
            coords_list.append(item)
    lat = float(coords_list[0])
    lon = float(coords_list[1])
    return lat, lon

def dist_grabber(house_coords):
    null_coords = (55.755831, 37.617673)
    
    # Радиус Земли
    R = 6371
    
    # Широта (latitude):
    lat1 = house_coords[0]
    lat2 = null_coords[0]

    # Долгота (longtude):
    lon1 = house_coords[1]
    lon2 = null_coords[1]
    
    d = np.arccos(
    np.sin(lat1)*np.sin(lat2) + np.cos(lat1)*np.cos(lat2)*np.cos(lat1-lat2)
    )
    L = d*R
    return(L)

# %% [markdown]
# ---

# %% [markdown]
# Общая площадь квартиры, кв. м. + Площадь кухни, кв. м. + Жилая площадь квартиры, кв. м.

# %%
def sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь']):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    # Список, куда будем класть наши значения искомых площадей
    sp_list = []
    
    # Перебираем три метста
    for s in sp_pl:
        
        # Поиск нужной цифры
        for i in range(1,len(table_td)):
            try:
                sp_str = re.findall(r'{}'.format(s) ,table_td[i].th.string)[0] # В качестве s ставим искмую сейчас площадь
                if sp_str == '{}'.format(s):
                    sp = re.findall(r'\d+\,?\d+\xa0м', str(table_td[i].td))

                    # Надстройка на случай, если графа с площадью пуста
                    if sp == []:
                        sp = np.nan
                        sp_list.append(sp) # Добавим в список значение так же, если нужной информации нет
                        break

                    sp = sp[0].replace(',', '.')
                    sp = float(re.findall(r'\d+\.?\d+', sp)[0])
                    
                    # Добавим в список значение очередной площади
                    sp_list.append(sp)
            except:
                pass
    
    # Словарь, в котором подпишем цифры удобным названием переменных
    sp_dist = {}
    sp_dist['totsp'] = sp_list[0]
    sp_dist['kitsp'] = sp_list[1]
    sp_dist['livesp'] = sp_list[2]
    
    # Вернем словарь со всеми нужными значениями
    return(sp_dist)

# %% [markdown]
# ---

# %% [markdown]
# Номер этажа, на котором расположена квартира + Всего этажей в доме

# %%
def floor_grabber(inner_table):
    
    try:
        # Теперь тут лежит внутренняя таблица (список td)
        table_td = inner_table.findAll('tr')

        # Вытаскиваем этажи
        for i in range(1,len(table_td)):
            try:
                th = re.findall(r'Этаж' ,table_td[i].th.string)[0]
                if th == 'Этаж':
                    floor_td = table_td[i].td # тег со всей информацией об этажах
                    floor_td = re.findall(r'\d+', str(floor_td)) # Теперь в переенной лежит список
                    # Одно число - только этаж квартиры, Два - еще суммарное количество этажей, Пустой - этой информции нет
            except:
                pass

        # Определяем какую информацию дать на выход
        if len(floor_td) == 0:
            floor = np.nan
            nfloor = np.nan
        elif len(floor_td) == 1:
            floor = int(floor_td[0])
            nfloor = np.nan
        else:
            floor = int(floor_td[0])
            nfloor = int(floor_td[1])
    except:
        floor = np.nan
        nfloor = np.nan

    return({'floor':floor, 'n_floor':nfloor})

# %% [markdown]
# ---

# %% [markdown]
# Балкон

# %%
def bal_grabber(inner_table):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    #Ищем нужный th с общей площадью квартиры
    for i in range(1,len(table_td)):
        # Положим сюда строку "Балкон" и поней будем искать нужный th
        # (на случай, если кол-во параметров может отличаться в разных квартирах)
        try:
            bal_str = re.findall(r'Балкон' ,table_td[i].th.string)[0]
            if bal_str == 'Балкон':
                bal = re.findall(r'i>\d+|есть', str(table_td[i].td))# Найдем кусок с метрами
                # Если балконов нет, то реулярное выражение ничего не найдет и вернет пустой список
                if bal == []:
                    bal = 0
                else:
                    bal = 1
        except:
            pass
        
    return(bal)

# %% [markdown]
# ---

# %% [markdown]
# Телефон

# %%
def tel_grabber(inner_table):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    # На некоторых страницах отстутствует графа "Телефон", поэтому введем проверку на наличие этой строки с помощью индикатора
    th_count = 0
    
    # Смотрим на td в поисках графы "Телефон"
    for i in range(1,len(table_td)):
        try:
            # Накручиваем значение индикатора
            th_count = th_count + 1
            
            th = re.findall(r'Телефон' ,table_td[i].th.string)[0]
            
            if th == 'Телефон':
                th_count = 0
                
                tel = table_td[i].td.string
                
                # Проверка на текст в нужном куске html кода
                if tel == 'да':
                    tel = 1
                else:
                    tel = 0
        except:
            pass
    
    # Проверка индикатора
    if th_count == len(table_td)-1:
        tel = 0
    
    return(tel)

# %% [markdown]
# ---

# %% [markdown]
# Рынок (первичный / вторичный)

# %%
def new_grabber(inner_table):
    
    # Теперь тут лежит внутренняя таблица (список td)
    table_td = inner_table.findAll('tr')
    
    # Идем по всем td в поисках графы 'Тип дома'
    for i in range(1,len(table_td)):
        try:
            new_str = re.findall(r'Тип дома' ,table_td[i].th.string)[0]
            if new_str == 'Тип дома':
                new = re.findall(r'вторич', str(table_td[i].td))
                
                # Проверка на наличия корня "вторич" в данной графе таблице
                if new == []:
                    new = 1
                else:
                    new = 0
        except:
            pass
        
    return(new)

# %% [markdown]
# ---

# %% [markdown]
# Район (Медведково, Митино и тд)

# %%
def small_dist_grabber(flat_page):
    
    # Ищем на странице нужный кусок html кода
    house_table = flat_page.findAll('div', class_='offer_container object_descr cleared')
    house_table = house_table[0].findAll('div', class_='bti__inner')
    
    # Проверка на случай, если искомая секция вобще отсутствует на странице данной квартиры
    if house_table == []:
        s_dist = np.nan
    else:
        # Углубляемся в нужный кусок html кода
        second_table = house_table[0].findAll('div', class_='bti__col')[1]
        second_table = second_table.findAll('tbody')[0]
        second_table_tr = second_table.findAll('tr')

        for i in range(0,len(second_table_tr)):
            try:
                s_dist_str = re.findall(r'Название', str(second_table_tr[i].th))[0]
                if s_dist_str == 'Название':
                    s_dist = second_table_tr[i].td.string
            except:
                pass
        
    return(s_dist)

# %% [markdown]
# ### Сбор квартир

# %% [markdown]
# - Lat - Широта
# - Lon - Долгота
# - District - Район (цао, вао и тд; нумерация соответствует значениям в списке district)
# - Small_district - Район (Медведково, Митино и тд)
# - N – номер квартиры по порядку
# - Rooms – число комнат
# - Price – цена
# - Totsp – общая площадь квартиры, кв. м.
# - Livesp – жилая площадь квартиры, кв. м.
# - Kitsp – площадь кухни, кв. м.
# - Dist – расстояние от центра в км. (можно по Пифагору)
# - Stname - Название ближайшей станции метро
# - Metrdist – расстояние до метро в минутах
# - Walk – 1 – если пешком от метро, 0 – если на транспорте
# - Brick – 1 – кирпичный/монолит/жб, 0 – другой
# - Tel – 1 – если есть, 0 – нет
# - Bal – 1 – есть балкон/лоджия, 0 – нет
# - Floor – номер этажа, на котором расположена квартира
# - Nfloors – всего этажей в доме
# - New – 1 – первичный рынок, 0 - вторичка
# - Price_duplicate - дубликат цены, полученный из соседнего тега (подробное обьяснение в описании функции) - для проверки
# - Link - ссылка на данную квартиру

# %%
flats_dict = {}
N = 0

errors = []

for l in links:
    
    try:
        # Это будет номер квартиры
        N = N + 1

        # Соберем все, что написано выше, вместе
        flat_page = requests.get(l[0])
        flat_page = flat_page.text
        flat_page = BeautifulSoup(flat_page, 'lxml')
        inf_table = flat_page.findAll('table', class_ = 'object_descr_tab')
        inf_table = inf_table[0]
        inner_table = inf_table.findAll('table', class_ = 'object_descr_props flat sale')
        inner_table = inner_table[0]

        house_coords = getCoords(flat_page)

        flats_dict[N] = {
            'Lat': house_coords[0],
            'Lon': house_coords[1],
            'District': l[1],
            'Small_district': small_dist_grabber(flat_page),
            'Rooms': room_grabber(inf_table),
            'Price': price_grabber(inf_table)[0],
            'Price_duplicate': price_grabber(inf_table)[1],
            'Totsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['totsp'],
            'Livesp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['kitsp'],
            'Kitsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['livesp'],
            'Dist': dist_grabber(house_coords),
            'Stname': metro(inf_table)['stname'],
            'Metrdist': metro(inf_table)['metrdist'],
            'Walk': metro(inf_table)['walk'],
            'Brick': brick_grabber(flat_page),
            'Tel': tel_grabber(inner_table),
            'Bal': bal_grabber(inner_table),
            'Floor': floor_grabber(inner_table)['floor'],
            'Nfloors': floor_grabber(inner_table)['n_floor'],
            'New': new_grabber(inner_table),
            'Link': l[0]
        }

        print('Page {} is working well'.format(N))
        
    except:
        errors.append(N)
        print('Page {} - ERROR!-ERROR!-ERROR!-ERROR!-ERROR!-ERROR!-ERROR!'.format(N))
# Out:
# Page 1 is working well
# Page 2 is working well
# Page 3 is working well
# Page 4 is working well
# Page 5 is working well
# Page 6 is working well
# Page 7 is working well
# Page 8 is working well
# Page 9 is working well
# Page 10 is working well
# Page 11 is working well
# Page 12 is working well
# Page 13 is working well
# Page 14 is working well
# Page 15 is working well
# Page 16 is working well
# Page 17 is working well
# Page 18 is working well
# Page 19 is working well
# Page 20 is working well
# Page 21 is working well
# Page 22 is working well
# Page 23 is working well
# Page 24 is working well
# Page 25 is working well
# Page 26 is working well
# Page 27 is working well
# Page 28 is working well
# Page 29 is working well
# Page 30 is working well
# Page 31 is working well
# Page 32 is working well
# Page 33 is working well
# Page 34 is working well
# Page 35 is working well
# Page 36 is working well
# Page 37 is working well
# Page 38 is working well
# Page 39 is working well
# Page 40 is working well
# Page 41 is working well
# Page 42 is working well
# Page 43 is working well
# Page 44 is working well
# Page 45 is working well
# Page 46 is working well
# Page 47 is working well
# Page 48 is working well
# Page 49 is working well
# Page 50 is working well
# Page 51 is working well
# Page 52 is working well
# Page 53 is working well
# Page 54 is working well
# Page 55 is working well
# Page 56 is working well
# Page 57 is working well
# Page 58 is working well
# Page 59 is working well
# Page 60 is working well
# Page 61 is working well
# Page 62 is working well
# Page 63 is working well
# Page 64 is working well
# Page 65 is working well
# Page 66 is working well
# Page 67 is working well
# Page 68 is working well
# Page 69 is working well
# Page 70 is working well
# Page 71 is working well
# Page 72 is working well
# Page 73 is working well
# Page 74 is working well
# Page 75 is working well
# Page 76 is working well
# Page 77 is working well
# Page 78 is working well
# Page 79 is working well
# Page 80 is working well
# Page 81 is working well
# Page 82 is working well
# Page 83 is working well
# Page 84 is working well
# Page 85 is working well
# Page 86 is working well
# Page 87 is working well
# Page 88 is working well
# Page 89 is working well
# Page 90 is working well
# Page 91 is working well
# Page 92 is working well
# Page 93 is working well
# Page 94 is working well
# Page 95 is working well
# Page 96 is working well
# Page 97 is working well
# Page 98 is working well
# Page 99 is working well
# Page 100 is working well
# Page 101 is working well
# Page 102 is working well
# Page 103 is working well
# Page 104 is working well
# Page 105 is working well
# Page 106 is working well
# Page 107 is working well
# Page 108 is working well
# Page 109 is working well
# Page 110 is working well
# Page 111 is working well
# Page 112 is working well
# Page 113 is working well
# Page 114 is working well
# Page 115 is working well
# Page 116 is working well
# Page 117 is working well
# Page 118 is working well
# Page 119 is working well
# Page 120 is working well
# Page 121 is working well
# Page 122 is working well
# Page 123 is working well
# Page 124 is working well
# Page 125 is working well
# Page 126 is working well
# Page 127 is working well
# Page 128 is working well
# Page 129 is working well
# Page 130 is working well
# Page 131 is working well
# Page 132 is working well
# Page 133 is working well
# Page 134 is working well
# Page 135 is working well
# Page 136 is working well
# Page 137 is working well
# Page 138 is working well
# Page 139 is working well
# Page 140 is working well
# Page 141 is working well
# Page 142 is working well
# Page 143 is working well
# Page 144 is working well
# Page 145 is working well
# Page 146 is working well
# Page 147 is working well
# Page 148 is working well
# Page 149 is working well
# Page 150 is working well
# Page 151 is working well
# Page 152 is working well
# Page 153 is working well
# Page 154 is working well
# Page 155 is working well
# Page 156 is working well
# Page 157 is working well
# Page 158 is working well
# Page 159 is working well
# Page 160 is working well
# Page 161 is working well
# Page 162 is working well
# Page 163 is working well
# Page 164 is working well
# Page 165 is working well
# Page 166 is working well
# Page 167 is working well
# Page 168 is working well
# Page 169 is working well
# Page 170 is working well
# Page 171 is working well
# Page 172 is working well
# Page 173 is working well
# Page 174 is working well
# Page 175 is working well
# Page 176 is working well
# Page 177 is working well
# Page 178 is working well
# Page 179 is working well
# Page 180 is working well
# Page 181 is working well
# Page 182 is working well
# Page 183 is working well
# Page 184 is working well
# Page 185 is working well
# Page 186 is working well
# Page 187 is working well
# Page 188 is working well
# Page 189 is working well
# Page 190 is working well
# Page 191 is working well
# Page 192 is working well
# Page 193 is working well
# Page 194 is working well
# Page 195 is working well
# Page 196 is working well
# Page 197 is working well
# Page 198 is working well
# Page 199 is working well
# Page 200 is working well
# Page 201 is working well
# Page 202 is working well
# Page 203 is working well
# Page 204 is working well
# Page 205 is working well
# Page 206 is working well
# Page 207 is working well
# Page 208 is working well
# Page 209 is working well
# Page 210 is working well
# Page 211 is working well
# Page 212 is working well
# Page 213 is working well
# Page 214 is working well
# Page 215 is working well
# Page 216 is working well
# Page 217 is working well
# Page 218 is working well
# Page 219 is working well
# Page 220 is working well
# Page 221 is working well
# Page 222 is working well
# Page 223 is working well
# Page 224 is working well
# Page 225 is working well
# Page 226 is working well
# Page 227 is working well
# Page 228 is working well
# Page 229 is working well
# Page 230 is working well
# Page 231 is working well
# Page 232 is working well
# Page 233 is working well
# Page 234 is working well
# Page 235 is working well
# Page 236 is working well
# Page 237 is working well
# Page 238 is working well
# Page 239 is working well
# Page 240 is working well
# Page 241 is working well
# Page 242 is working well
# Page 243 is working well
# Page 244 is working well
# Page 245 is working well
# Page 246 is working well
# Page 247 is working well
# Page 248 is working well
# Page 249 is working well
# Page 250 is working well
# Page 251 is working well
# Page 252 is working well
# Page 253 is working well
# Page 254 is working well
# Page 255 is working well
# Page 256 is working well
# Page 257 is working well
# Page 258 is working well
# Page 259 is working well
# Page 260 is working well
# Page 261 is working well
# Page 262 is working well
# Page 263 is working well
# Page 264 is working well
# Page 265 is working well
# Page 266 is working well
# Page 267 is working well
# Page 268 is working well
# Page 269 is working well
# Page 270 is working well
# Page 271 is working well
# Page 272 is working well
# Page 273 is working well
# Page 274 is working well
# Page 275 is working well
# Page 276 is working well
# Page 277 is working well
# Page 278 is working well
# Page 279 is working well
# Page 280 is working well
# Page 281 is working well
# Page 282 is working well
# Page 283 is working well
# Page 284 is working well
# Page 285 is working well
# Page 286 is working well
# Page 287 is working well
# Page 288 is working well
# Page 289 is working well
# Page 290 is working well
# Page 291 is working well
# Page 292 is working well
# Page 293 is working well
# Page 294 is working well
# Page 295 is working well
# Page 296 is working well
# Page 297 is working well
# Page 298 is working well
# Page 299 is working well
# Page 300 is working well
# Page 301 is working well
# Page 302 is working well
# Page 303 is working well
# Page 304 is working well
# Page 305 is working well
# Page 306 is working well
# Page 307 is working well
# Page 308 is working well
# Page 309 is working well
# Page 310 is working well
# Page 311 is working well
# Page 312 is working well
# Page 313 is working well
# Page 314 is working well
# Page 315 is working well
# Page 316 is working well
# Page 317 is working well
# Page 318 is working well
# Page 319 is working well
# Page 320 is working well
# Page 321 is working well
# Page 322 is working well
# Page 323 is working well
# Page 324 is working well
# Page 325 is working well
# Page 326 is working well
# Page 327 is working well
# Page 328 is working well
# Page 329 is working well
# Page 330 is working well
# Page 331 is working well
# Page 332 is working well
# Page 333 is working well
# Page 334 is working well
# Page 335 is working well
# Page 336 is working well
# Page 337 is working well
# Page 338 is working well
# Page 339 is working well
# Page 340 is working well
# Page 341 is working well
# Page 342 is working well
# Page 343 is working well
# Page 344 is working well
# Page 345 is working well
# Page 346 is working well
# Page 347 is working well
# Page 348 is working well
# Page 349 is working well
# Page 350 is working well
# Page 351 is working well
# Page 352 is working well
# Page 353 is working well
# Page 354 is working well
# Page 355 is working well
# Page 356 is working well
# Page 357 is working well
# Page 358 is working well
# Page 359 is working well
# Page 360 is working well
# Page 361 is working well
# Page 362 is working well
# Page 363 is working well
# Page 364 is working well
# Page 365 is working well
# Page 366 is working well
# Page 367 is working well
# Page 368 is working well
# Page 369 is working well
# Page 370 is working well
# Page 371 is working well
# Page 372 is working well
# Page 373 is working well
# Page 374 is working well
# Page 375 is working well
# Page 376 is working well
# Page 377 is working well
# Page 378 is working well
# Page 379 is working well
# Page 380 is working well
# Page 381 is working well
# Page 382 is working well
# Page 383 is working well
# Page 384 is working well
# Page 385 is working well
# Page 386 is working well
# Page 387 is working well
# Page 388 is working well
# Page 389 is working well
# Page 390 is working well
# Page 391 is working well
# Page 392 is working well
# Page 393 is working well
# Page 394 is working well
# Page 395 is working well
# Page 396 is working well
# Page 397 is working well
# Page 398 is working well
# Page 399 is working well
# Page 400 is working well
# Page 401 is working well
# Page 402 is working well
# Page 403 is working well
# Page 404 is working well
# Page 405 is working well
# Page 406 is working well
# Page 407 is working well
# Page 408 is working well
# Page 409 is working well
# Page 410 is working well
# Page 411 is working well
# Page 412 is working well
# Page 413 is working well
# Page 414 is working well
# Page 415 is working well
# Page 416 is working well
# Page 417 is working well
# Page 418 is working well
# Page 419 is working well
# Page 420 is working well
# Page 421 is working well
# Page 422 is working well
# Page 423 is working well
# Page 424 is working well
# Page 425 is working well
# Page 426 is working well
# Page 427 is working well
# Page 428 is working well
# Page 429 is working well
# Page 430 is working well
# Page 431 is working well
# Page 432 is working well
# Page 433 is working well
# Page 434 is working well
# Page 435 is working well
# Page 436 is working well
# Page 437 is working well
# Page 438 is working well
# Page 439 is working well
# Page 440 is working well
# Page 441 is working well
# Page 442 is working well
# Page 443 is working well
# Page 444 is working well
# Page 445 is working well
# Page 446 is working well
# Page 447 is working well
# Page 448 is working well
# Page 449 is working well
# Page 450 is working well
# Page 451 is working well
# Page 452 is working well
# Page 453 is working well
# Page 454 is working well
# Page 455 is working well
# Page 456 is working well
# Page 457 is working well
# Page 458 is working well
# Page 459 is working well
# Page 460 is working well
# Page 461 is working well
# Page 462 is working well
# Page 463 is working well
# Page 464 is working well
# Page 465 is working well
# Page 466 is working well
# Page 467 is working well
# Page 468 is working well
# Page 469 is working well
# Page 470 is working well
# Page 471 is working well
# Page 472 is working well
# Page 473 is working well
# Page 474 is working well
# Page 475 is working well
# Page 476 is working well
# Page 477 is working well
# Page 478 is working well
# Page 479 is working well
# Page 480 is working well
# Page 481 is working well
# Page 482 is working well
# Page 483 is working well
# Page 484 is working well
# Page 485 is working well
# Page 486 is working well
# Page 487 is working well
# Page 488 is working well
# Page 489 is working well
# Page 490 is working well
# Page 491 is working well
# Page 492 is working well
# Page 493 is working well
# Page 494 is working well
# Page 495 is working well
# Page 496 is working well
# Page 497 is working well
# Page 498 is working well
# Page 499 is working well
# Page 500 is working well
# Page 501 is working well
# Page 502 is working well
# Page 503 is working well
# Page 504 is working well
# Page 505 is working well
# Page 506 is working well
# Page 507 is working well
# Page 508 is working well
# Page 509 is working well
# Page 510 is working well
# Page 511 is working well
# Page 512 is working well
# Page 513 is working well
# Page 514 is working well
# Page 515 is working well
# Page 516 is working well
# Page 517 is working well
# Page 518 is working well
# Page 519 is working well
# Page 520 is working well
# Page 521 is working well
# Page 522 is working well
# Page 523 is working well
# Page 524 is working well
# Page 525 is working well
# Page 526 is working well
# Page 527 is working well
# Page 528 is working well
# Page 529 is working well
# Page 530 is working well
# Page 531 is working well
# Page 532 is working well
# Page 533 is working well
# Page 534 is working well
# Page 535 is working well
# Page 536 is working well
# Page 537 is working well
# Page 538 is working well
# Page 539 is working well
# Page 540 is working well
# Page 541 is working well
# Page 542 is working well
# Page 543 is working well
# Page 544 is working well
# Page 545 is working well
# Page 546 is working well
# Page 547 is working well
# Page 548 is working well
# Page 549 is working well
# Page 550 is working well
# Page 551 is working well
# Page 552 is working well
# Page 553 is working well
# Page 554 is working well
# Page 555 is working well
# Page 556 is working well
# Page 557 is working well
# Page 558 is working well
# Page 559 is working well
# Page 560 is working well
# Page 561 is working well
# Page 562 is working well
# Page 563 is working well
# Page 564 is working well
# Page 565 is working well
# Page 566 is working well
# Page 567 is working well
# Page 568 is working well
# Page 569 is working well
# Page 570 is working well
# Page 571 is working well
# Page 572 is working well
# Page 573 is working well
# Page 574 is working well
# Page 575 is working well
# Page 576 is working well
# Page 577 is working well
# Page 578 is working well
# Page 579 is working well
# Page 580 is working well
# Page 581 is working well
# Page 582 is working well
# Page 583 is working well
# Page 584 is working well
# Page 585 is working well
# Page 586 is working well
# Page 587 is working well
# Page 588 is working well
# Page 589 is working well
# Page 590 is working well
# Page 591 is working well
# Page 592 is working well
# Page 593 is working well
# Page 594 is working well
# Page 595 is working well
# Page 596 is working well
# Page 597 is working well
# Page 598 is working well
# Page 599 is working well
# Page 600 is working well
# Page 601 is working well
# Page 602 is working well
# Page 603 is working well
# Page 604 is working well
# Page 605 is working well
# Page 606 is working well
# Page 607 is working well
# Page 608 is working well
# Page 609 is working well
# Page 610 is working well
# Page 611 is working well
# Page 612 is working well
# Page 613 is working well
# Page 614 is working well
# Page 615 is working well
# Page 616 is working well
# Page 617 is working well
# Page 618 is working well
# Page 619 is working well
# Page 620 is working well
# Page 621 is working well
# Page 622 is working well
# Page 623 is working well
# Page 624 is working well
# Page 625 is working well
# Page 626 is working well
# Page 627 is working well
# Page 628 is working well
# Page 629 is working well
# Page 630 is working well
# Page 631 is working well
# Page 632 is working well
# Page 633 is working well
# Page 634 is working well
# Page 635 is working well
# Page 636 is working well
# Page 637 is working well
# Page 638 is working well
# Page 639 is working well
# Page 640 is working well
# Page 641 is working well
# Page 642 is working well
# Page 643 is working well
# Page 644 is working well
# Page 645 is working well
# Page 646 is working well
# Page 647 is working well
# Page 648 is working well
# Page 649 is working well
# Page 650 is working well
# Page 651 is working well
# Page 652 is working well
# Page 653 is working well
# Page 654 is working well
# Page 655 is working well
# Page 656 is working well
# Page 657 is working well
# Page 658 is working well
# Page 659 is working well
# Page 660 is working well
# Page 661 is working well
# Page 662 is working well
# Page 663 is working well
# Page 664 is working well
# Page 665 is working well
# Page 666 is working well
# Page 667 is working well
# Page 668 is working well
# Page 669 is working well
# Page 670 is working well
# Page 671 is working well
# Page 672 is working well
# Page 673 is working well
# Page 674 is working well
# Page 675 is working well
# Page 676 is working well
# Page 677 is working well
# Page 678 is working well
# Page 679 is working well
# Page 680 is working well
# Page 681 is working well
# Page 682 is working well
# Page 683 is working well
# Page 684 is working well
# Page 685 is working well
# Page 686 is working well
# Page 687 is working well
# Page 688 is working well
# Page 689 is working well
# Page 690 is working well
# Page 691 is working well
# Page 692 is working well
# Page 693 is working well
# Page 694 is working well
# Page 695 is working well
# Page 696 is working well
# Page 697 is working well
# Page 698 is working well
# Page 699 is working well
# Page 700 is working well
# Page 701 is working well
# Page 702 is working well
# Page 703 is working well
# Page 704 is working well
# Page 705 is working well
# Page 706 is working well
# Page 707 is working well
# Page 708 is working well
# Page 709 is working well
# Page 710 is working well
# Page 711 is working well
# Page 712 is working well
# Page 713 is working well
# Page 714 is working well
# Page 715 is working well
# Page 716 is working well
# Page 717 is working well
# Page 718 is working well
# Page 719 is working well
# Page 720 is working well
# Page 721 is working well
# Page 722 is working well
# Page 723 is working well
# Page 724 is working well
# Page 725 is working well
# Page 726 is working well
# Page 727 is working well
# Page 728 is working well
# Page 729 is working well
# Page 730 is working well
# Page 731 is working well
# Page 732 is working well
# Page 733 is working well
# Page 734 is working well
# Page 735 is working well
# Page 736 is working well
# Page 737 is working well
# Page 738 is working well
# Page 739 is working well
# Page 740 is working well
# Page 741 is working well
# Page 742 is working well
# Page 743 is working well
# Page 744 is working well
# Page 745 is working well
# Page 746 is working well
# Page 747 is working well
# Page 748 is working well
# Page 749 is working well
# Page 750 is working well
# Page 751 is working well
# Page 752 is working well
# Page 753 is working well
# Page 754 is working well
# Page 755 is working well
# Page 756 is working well
# Page 757 is working well
# Page 758 is working well
# Page 759 is working well
# Page 760 is working well
# Page 761 is working well
# Page 762 is working well
# Page 763 is working well
# Page 764 is working well
# Page 765 is working well
# Page 766 is working well
# Page 767 is working well
# Page 768 is working well
# Page 769 is working well
# Page 770 is working well
# Page 771 is working well
# Page 772 is working well
# Page 773 is working well
# Page 774 is working well
# Page 775 is working well
# Page 776 is working well
# Page 777 is working well
# Page 778 is working well
# Page 779 is working well
# Page 780 is working well
# Page 781 is working well
# Page 782 is working well
# Page 783 is working well
# Page 784 is working well
# Page 785 is working well
# Page 786 is working well
# Page 787 is working well
# Page 788 is working well
# Page 789 is working well
# Page 790 is working well
# Page 791 is working well
# Page 792 is working well
# Page 793 is working well
# Page 794 is working well
# Page 795 is working well
# Page 796 is working well
# Page 797 is working well
# Page 798 is working well
# Page 799 is working well
# Page 800 is working well
# Page 801 is working well
# Page 802 is working well
# Page 803 is working well
# Page 804 is working well
# Page 805 is working well
# Page 806 is working well
# Page 807 is working well
# Page 808 is working well
# Page 809 is working well
# Page 810 is working well
# Page 811 is working well
# Page 812 is working well
# Page 813 is working well
# Page 814 is working well
# Page 815 is working well
# Page 816 is working well
# Page 817 is working well
# Page 818 is working well
# Page 819 is working well
# Page 820 is working well
# Page 821 is working well
# Page 822 is working well
# Page 823 is working well
# Page 824 is working well
# Page 825 is working well
# Page 826 is working well
# Page 827 is working well
# Page 828 is working well
# Page 829 is working well
# Page 830 is working well
# Page 831 is working well
# Page 832 is working well
# Page 833 is working well
# Page 834 is working well
# Page 835 is working well
# Page 836 is working well
# Page 837 is working well
# Page 838 is working well
# Page 839 is working well
# Page 840 is working well
# Page 841 is working well
# Page 842 is working well
# Page 843 is working well
# Page 844 is working well
# Page 845 is working well
# Page 846 is working well
# Page 847 is working well
# Page 848 is working well
# Page 849 is working well
# Page 850 is working well
# Page 851 is working well
# Page 852 is working well
# Page 853 is working well
# Page 854 is working well
# Page 855 is working well
# Page 856 is working well
# Page 857 is working well
# Page 858 is working well
# Page 859 is working well
# Page 860 is working well
# Page 861 is working well
# Page 862 is working well
# Page 863 is working well
# Page 864 is working well
# Page 865 is working well
# Page 866 is working well
# Page 867 is working well
# Page 868 is working well
# Page 869 is working well
# Page 870 is working well
# Page 871 is working well
# Page 872 is working well
# Page 873 is working well
# Page 874 is working well
# Page 875 is working well
# Page 876 is working well
# Page 877 is working well
# Page 878 is working well
# Page 879 is working well
# Page 880 is working well
# Page 881 is working well
# Page 882 is working well
# Page 883 is working well
# Page 884 is working well
# Page 885 is working well
# Page 886 is working well
# Page 887 is working well
# Page 888 is working well
# Page 889 is working well
# Page 890 is working well
# Page 891 is working well
# Page 892 is working well
# Page 893 is working well
# Page 894 is working well
# Page 895 is working well
# Page 896 is working well
# Page 897 is working well
# Page 898 is working well
# Page 899 is working well
# Page 900 is working well
# Page 901 is working well
# Page 902 is working well
# Page 903 is working well
# Page 904 is working well
# Page 905 is working well
# Page 906 is working well
# Page 907 is working well
# Page 908 is working well
# Page 909 is working well
# Page 910 is working well
# Page 911 is working well
# Page 912 is working well
# Page 913 is working well
# Page 914 is working well
# Page 915 is working well
# Page 916 is working well
# Page 917 is working well
# Page 918 is working well
# Page 919 is working well
# Page 920 is working well
# Page 921 is working well
# Page 922 is working well
# Page 923 is working well
# Page 924 is working well
# Page 925 is working well
# Page 926 is working well
# Page 927 is working well
# Page 928 is working well
# Page 929 is working well
# Page 930 is working well
# Page 931 is working well
# Page 932 is working well
# Page 933 is working well
# Page 934 is working well
# Page 935 is working well
# Page 936 is working well
# Page 937 is working well
# Page 938 is working well
# Page 939 is working well
# Page 940 is working well
# Page 941 is working well
# Page 942 is working well
# Page 943 is working well
# Page 944 is working well
# Page 945 is working well
# Page 946 is working well
# Page 947 is working well
# Page 948 is working well
# Page 949 is working well
# Page 950 is working well
# Page 951 is working well
# Page 952 is working well
# Page 953 is working well
# Page 954 is working well
# Page 955 is working well
# Page 956 is working well
# Page 957 is working well
# Page 958 is working well
# Page 959 is working well
# Page 960 is working well
# Page 961 is working well
# Page 962 is working well
# Page 963 is working well
# Page 964 is working well
# Page 965 is working well
# Page 966 is working well
# Page 967 is working well
# Page 968 is working well
# Page 969 is working well
# Page 970 is working well
# Page 971 is working well
# Page 972 is working well
# Page 973 is working well
# Page 974 is working well
# Page 975 is working well
# Page 976 is working well
# Page 977 is working well
# Page 978 is working well
# Page 979 is working well
# Page 980 is working well
# Page 981 is working well
# Page 982 is working well
# Page 983 is working well
# Page 984 is working well
# Page 985 is working well
# Page 986 is working well
# Page 987 is working well
# Page 988 is working well
# Page 989 is working well
# Page 990 is working well
# Page 991 is working well
# Page 992 is working well
# Page 993 is working well
# Page 994 is working well
# Page 995 is working well
# Page 996 is working well
# Page 997 is working well
# Page 998 is working well
# Page 999 is working well
# Page 1000 is working well
# Page 1001 is working well
# Page 1002 is working well
# Page 1003 is working well
# Page 1004 is working well
# Page 1005 is working well
# Page 1006 is working well
# Page 1007 is working well
# Page 1008 is working well
# Page 1009 is working well
# Page 1010 is working well
# Page 1011 is working well
# Page 1012 is working well
# Page 1013 is working well
# Page 1014 is working well
# Page 1015 is working well
# Page 1016 is working well
# Page 1017 is working well
# Page 1018 is working well
# Page 1019 is working well
# Page 1020 is working well
# Page 1021 is working well
# Page 1022 is working well
# Page 1023 is working well
# Page 1024 is working well
# Page 1025 is working well
# Page 1026 is working well
# Page 1027 is working well
# Page 1028 is working well
# Page 1029 is working well
# Page 1030 is working well
# Page 1031 is working well
# Page 1032 is working well
# Page 1033 is working well
# Page 1034 is working well
# Page 1035 is working well
# Page 1036 is working well
# Page 1037 is working well
# Page 1038 is working well
# Page 1039 is working well
# Page 1040 is working well
# Page 1041 is working well
# Page 1042 is working well
# Page 1043 is working well
# Page 1044 is working well
# Page 1045 is working well
# Page 1046 is working well
# Page 1047 is working well
# Page 1048 is working well
# Page 1049 is working well
# Page 1050 is working well
# Page 1051 is working well
# Page 1052 is working well
# Page 1053 is working well
# Page 1054 is working well
# Page 1055 is working well
# Page 1056 is working well
# Page 1057 is working well
# Page 1058 is working well
# Page 1059 is working well
# Page 1060 is working well
# Page 1061 is working well
# Page 1062 is working well
# Page 1063 is working well
# Page 1064 is working well
# Page 1065 is working well
# Page 1066 is working well
# Page 1067 is working well
# Page 1068 is working well
# Page 1069 is working well
# Page 1070 is working well
# Page 1071 is working well
# Page 1072 is working well
# Page 1073 is working well
# Page 1074 is working well
# Page 1075 is working well
# Page 1076 is working well
# Page 1077 is working well
# Page 1078 is working well
# Page 1079 is working well
# Page 1080 is working well
# Page 1081 is working well
# Page 1082 is working well
# Page 1083 is working well
# Page 1084 is working well
# Page 1085 is working well
# Page 1086 is working well
# Page 1087 is working well
# Page 1088 is working well
# Page 1089 is working well
# Page 1090 is working well
# Page 1091 is working well
# Page 1092 is working well
# Page 1093 is working well
# Page 1094 is working well
# Page 1095 is working well
# Page 1096 is working well
# Page 1097 is working well
# Page 1098 is working well
# Page 1099 is working well
# Page 1100 is working well
# Page 1101 is working well
# Page 1102 is working well
# Page 1103 is working well
# Page 1104 is working well
# Page 1105 is working well
# Page 1106 is working well
# Page 1107 is working well
# Page 1108 is working well
# Page 1109 is working well
# Page 1110 is working well
# Page 1111 is working well
# Page 1112 is working well
# Page 1113 is working well
# Page 1114 is working well
# Page 1115 is working well
# Page 1116 is working well
# Page 1117 is working well
# Page 1118 is working well
# Page 1119 is working well
# Page 1120 is working well
# Page 1121 is working well
# Page 1122 is working well
# Page 1123 is working well
# Page 1124 is working well
# Page 1125 is working well
# Page 1126 is working well
# Page 1127 is working well
# Page 1128 is working well
# Page 1129 is working well
# Page 1130 is working well
# Page 1131 is working well
# Page 1132 is working well
# Page 1133 is working well
# Page 1134 is working well
# Page 1135 is working well
# Page 1136 is working well
# Page 1137 is working well
# Page 1138 is working well
# Page 1139 is working well
# Page 1140 is working well
# Page 1141 is working well
# Page 1142 is working well
# Page 1143 is working well
# Page 1144 is working well
# Page 1145 is working well
# Page 1146 is working well
# Page 1147 is working well
# Page 1148 is working well
# Page 1149 is working well
# Page 1150 is working well
# Page 1151 is working well
# Page 1152 is working well
# Page 1153 is working well
# Page 1154 is working well
# Page 1155 is working well
# Page 1156 is working well
# Page 1157 is working well
# Page 1158 is working well
# Page 1159 is working well
# Page 1160 is working well
# Page 1161 is working well
# Page 1162 is working well
# Page 1163 is working well
# Page 1164 is working well
# Page 1165 is working well
# Page 1166 is working well
# Page 1167 is working well
# Page 1168 is working well
# Page 1169 is working well
# Page 1170 is working well
# Page 1171 is working well
# Page 1172 is working well
# Page 1173 is working well
# Page 1174 is working well
# Page 1175 is working well
# Page 1176 is working well
# Page 1177 is working well
# Page 1178 is working well
# Page 1179 is working well
# Page 1180 is working well
# Page 1181 is working well
# Page 1182 is working well
# Page 1183 is working well
# Page 1184 is working well
# Page 1185 is working well
# Page 1186 is working well
# Page 1187 is working well
# Page 1188 is working well
# Page 1189 is working well
# Page 1190 is working well
# Page 1191 is working well
# Page 1192 is working well
# Page 1193 is working well
# Page 1194 is working well
# Page 1195 is working well
# Page 1196 is working well
# Page 1197 is working well
# Page 1198 is working well
# Page 1199 is working well
# Page 1200 is working well
# Page 1201 is working well
# Page 1202 is working well
# Page 1203 is working well
# Page 1204 is working well
# Page 1205 is working well
# Page 1206 is working well
# Page 1207 is working well
# Page 1208 is working well
# Page 1209 is working well
# Page 1210 is working well
# Page 1211 is working well
# Page 1212 is working well
# Page 1213 is working well
# Page 1214 is working well
# Page 1215 is working well
# Page 1216 is working well
# Page 1217 is working well
# Page 1218 is working well
# Page 1219 is working well
# Page 1220 is working well
# Page 1221 is working well
# Page 1222 is working well
# Page 1223 is working well
# Page 1224 is working well
# Page 1225 is working well
# Page 1226 is working well
# Page 1227 is working well
# Page 1228 is working well
# Page 1229 is working well
# Page 1230 is working well
# Page 1231 is working well
# Page 1232 is working well
# Page 1233 is working well
# Page 1234 is working well
# Page 1235 is working well
# Page 1236 is working well
# Page 1237 is working well
# Page 1238 is working well
# Page 1239 is working well
# Page 1240 is working well
# Page 1241 is working well
# Page 1242 is working well
# Page 1243 is working well
# Page 1244 is working well
# Page 1245 is working well
# Page 1246 is working well
# Page 1247 is working well
# Page 1248 is working well
# Page 1249 is working well
# Page 1250 is working well
# Page 1251 is working well
# Page 1252 is working well
# Page 1253 is working well
# Page 1254 is working well
# Page 1255 is working well
# Page 1256 is working well
# Page 1257 is working well
# Page 1258 is working well
# Page 1259 is working well
# Page 1260 is working well
# Page 1261 is working well
# Page 1262 is working well
# Page 1263 is working well
# Page 1264 is working well
# Page 1265 is working well
# Page 1266 is working well
# Page 1267 is working well
# Page 1268 is working well
# Page 1269 is working well
# Page 1270 is working well
# Page 1271 is working well
# Page 1272 is working well
# Page 1273 is working well
# Page 1274 is working well
# Page 1275 is working well
# Page 1276 is working well
# Page 1277 is working well
# Page 1278 is working well
# Page 1279 is working well
# Page 1280 is working well
# Page 1281 is working well
# Page 1282 is working well
# Page 1283 is working well
# Page 1284 is working well
# Page 1285 is working well
# Page 1286 is working well
# Page 1287 is working well
# Page 1288 is working well
# Page 1289 is working well
# Page 1290 is working well
# Page 1291 is working well
# Page 1292 is working well
# Page 1293 is working well
# Page 1294 is working well
# Page 1295 is working well
# Page 1296 is working well
# Page 1297 is working well
# Page 1298 is working well
# Page 1299 is working well
# Page 1300 is working well
# Page 1301 is working well
# Page 1302 is working well
# Page 1303 is working well
# Page 1304 is working well
# Page 1305 is working well
# Page 1306 is working well
# Page 1307 is working well
# Page 1308 is working well
# Page 1309 is working well
# Page 1310 is working well
# Page 1311 is working well
# Page 1312 is working well
# Page 1313 is working well
# Page 1314 is working well
# Page 1315 is working well
# Page 1316 is working well
# Page 1317 is working well
# Page 1318 is working well
# Page 1319 is working well
# Page 1320 is working well
# Page 1321 is working well
# Page 1322 is working well
# Page 1323 is working well
# Page 1324 is working well
# Page 1325 is working well
# Page 1326 is working well
# Page 1327 is working well
# Page 1328 is working well
# Page 1329 is working well
# Page 1330 is working well
# Page 1331 is working well
# Page 1332 is working well
# Page 1333 is working well
# Page 1334 is working well
# Page 1335 is working well
# Page 1336 is working well
# Page 1337 is working well
# Page 1338 is working well
# Page 1339 is working well
# Page 1340 is working well
# Page 1341 is working well
# Page 1342 is working well
# Page 1343 is working well
# Page 1344 is working well
# Page 1345 is working well
# Page 1346 is working well
# Page 1347 is working well
# Page 1348 is working well
# Page 1349 is working well
# Page 1350 is working well
# Page 1351 is working well
# Page 1352 is working well
# Page 1353 is working well
# Page 1354 is working well
# Page 1355 is working well
# Page 1356 is working well
# Page 1357 is working well
# Page 1358 is working well
# Page 1359 is working well
# Page 1360 is working well
# Page 1361 is working well
# Page 1362 is working well
# Page 1363 is working well
# Page 1364 is working well
# Page 1365 is working well
# Page 1366 is working well
# Page 1367 is working well
# Page 1368 is working well
# Page 1369 is working well
# Page 1370 is working well
# Page 1371 is working well
# Page 1372 is working well
# Page 1373 is working well
# Page 1374 is working well
# Page 1375 is working well
# Page 1376 is working well
# Page 1377 is working well
# Page 1378 is working well
# Page 1379 is working well
# Page 1380 is working well
# Page 1381 is working well
# Page 1382 is working well
# Page 1383 is working well
# Page 1384 is working well
# Page 1385 is working well
# Page 1386 is working well
# Page 1387 is working well
# Page 1388 is working well
# Page 1389 is working well
# Page 1390 is working well
# Page 1391 is working well
# Page 1392 is working well
# Page 1393 is working well
# Page 1394 is working well
# Page 1395 is working well
# Page 1396 is working well
# Page 1397 is working well
# Page 1398 is working well
# Page 1399 is working well
# Page 1400 is working well
# Page 1401 is working well
# Page 1402 is working well
# Page 1403 is working well
# Page 1404 is working well
# Page 1405 is working well
# Page 1406 is working well
# Page 1407 is working well
# Page 1408 is working well
# Page 1409 is working well
# Page 1410 is working well
# Page 1411 is working well
# Page 1412 is working well
# Page 1413 is working well
# Page 1414 is working well
# Page 1415 is working well
# Page 1416 is working well
# Page 1417 is working well
# Page 1418 is working well
# Page 1419 is working well
# Page 1420 is working well
# Page 1421 is working well
# Page 1422 is working well
# Page 1423 is working well
# Page 1424 is working well
# Page 1425 is working well
# Page 1426 is working well
# Page 1427 is working well
# Page 1428 is working well
# Page 1429 is working well
# Page 1430 is working well
# Page 1431 is working well
# Page 1432 is working well
# Page 1433 is working well
# Page 1434 is working well
# Page 1435 is working well
# Page 1436 is working well
# Page 1437 is working well
# Page 1438 is working well
# Page 1439 is working well
# Page 1440 is working well
# Page 1441 is working well
# Page 1442 is working well
# Page 1443 is working well
# Page 1444 is working well
# Page 1445 is working well
# Page 1446 is working well
# Page 1447 is working well
# Page 1448 is working well
# Page 1449 is working well
# Page 1450 is working well
# Page 1451 is working well
# Page 1452 is working well
# Page 1453 is working well
# Page 1454 is working well
# Page 1455 is working well
# Page 1456 is working well
# Page 1457 is working well
# Page 1458 is working well
# Page 1459 is working well
# Page 1460 is working well
# Page 1461 is working well
# Page 1462 is working well
# Page 1463 is working well
# Page 1464 is working well
# Page 1465 is working well
# Page 1466 is working well
# Page 1467 is working well
# Page 1468 is working well
# Page 1469 is working well
# Page 1470 is working well
# Page 1471 is working well
# Page 1472 is working well
# Page 1473 is working well
# Page 1474 is working well
# Page 1475 is working well
# Page 1476 is working well
# Page 1477 is working well
# Page 1478 is working well
# Page 1479 is working well
# Page 1480 is working well
# Page 1481 is working well
# Page 1482 is working well
# Page 1483 is working well
# Page 1484 is working well
# Page 1485 is working well
# Page 1486 is working well
# Page 1487 is working well
# Page 1488 is working well
# Page 1489 is working well
# Page 1490 is working well
# Page 1491 is working well
# Page 1492 is working well
# Page 1493 is working well
# Page 1494 is working well
# Page 1495 is working well
# Page 1496 is working well
# Page 1497 is working well
# Page 1498 is working well
# Page 1499 is working well
# Page 1500 is working well
# Page 1501 is working well
# Page 1502 is working well
# Page 1503 is working well
# Page 1504 is working well
# Page 1505 is working well
# Page 1506 is working well
# Page 1507 is working well
# Page 1508 is working well
# Page 1509 is working well
# Page 1510 is working well
# Page 1511 is working well
# Page 1512 is working well
# Page 1513 is working well
# Page 1514 is working well
# Page 1515 is working well
# Page 1516 is working well
# Page 1517 is working well
# Page 1518 is working well
# Page 1519 is working well
# Page 1520 is working well
# Page 1521 is working well
# Page 1522 is working well
# Page 1523 is working well
# Page 1524 is working well
# Page 1525 is working well
# Page 1526 is working well
# Page 1527 is working well
# Page 1528 is working well
# Page 1529 is working well
# Page 1530 is working well
# Page 1531 is working well
# Page 1532 is working well
# Page 1533 is working well
# Page 1534 is working well
# Page 1535 is working well
# Page 1536 is working well
# Page 1537 is working well
# Page 1538 is working well
# Page 1539 is working well
# Page 1540 is working well
# Page 1541 is working well
# Page 1542 is working well
# Page 1543 is working well
# Page 1544 is working well
# Page 1545 is working well
# Page 1546 is working well
# Page 1547 is working well
# Page 1548 is working well
# Page 1549 is working well
# Page 1550 is working well
# Page 1551 is working well
# Page 1552 is working well
# Page 1553 is working well
# Page 1554 is working well
# Page 1555 is working well
# Page 1556 is working well
# Page 1557 is working well
# Page 1558 is working well
# Page 1559 is working well
# Page 1560 is working well
# Page 1561 is working well
# Page 1562 is working well
# Page 1563 is working well
# Page 1564 is working well
# Page 1565 is working well
# Page 1566 is working well
# Page 1567 is working well
# Page 1568 is working well
# Page 1569 is working well
# Page 1570 is working well
# Page 1571 is working well
# Page 1572 is working well
# Page 1573 is working well
# Page 1574 is working well
# Page 1575 is working well
# Page 1576 is working well
# Page 1577 is working well
# Page 1578 is working well
# Page 1579 is working well
# Page 1580 is working well
# Page 1581 is working well
# Page 1582 is working well
# Page 1583 is working well
# Page 1584 is working well
# Page 1585 is working well
# Page 1586 is working well
# Page 1587 is working well
# Page 1588 is working well
# Page 1589 is working well
# Page 1590 is working well
# Page 1591 is working well
# Page 1592 is working well
# Page 1593 is working well
# Page 1594 is working well
# Page 1595 is working well
# Page 1596 is working well
# Page 1597 is working well
# Page 1598 is working well
# Page 1599 is working well
# Page 1600 is working well
# Page 1601 is working well
# Page 1602 is working well
# Page 1603 is working well
# Page 1604 is working well
# Page 1605 is working well
# Page 1606 is working well
# Page 1607 is working well
# Page 1608 is working well
# Page 1609 is working well
# Page 1610 is working well
# Page 1611 is working well
# Page 1612 is working well
# Page 1613 is working well
# Page 1614 is working well
# Page 1615 is working well
# Page 1616 is working well
# Page 1617 is working well
# Page 1618 is working well
# Page 1619 is working well
# Page 1620 is working well
# Page 1621 is working well
# Page 1622 is working well
# Page 1623 is working well
# Page 1624 is working well
# Page 1625 is working well
# Page 1626 is working well
# Page 1627 is working well
# Page 1628 is working well
# Page 1629 is working well
# Page 1630 is working well
# Page 1631 is working well
# Page 1632 is working well
# Page 1633 is working well
# Page 1634 is working well
# Page 1635 is working well
# Page 1636 is working well
# Page 1637 is working well
# Page 1638 is working well
# Page 1639 is working well
# Page 1640 is working well
# Page 1641 is working well
# Page 1642 is working well
# Page 1643 is working well
# Page 1644 is working well
# Page 1645 is working well
# Page 1646 is working well
# Page 1647 is working well
# Page 1648 is working well
# Page 1649 is working well
# Page 1650 is working well
# Page 1651 is working well
# Page 1652 is working well
# Page 1653 is working well
# Page 1654 is working well
# Page 1655 is working well
# Page 1656 is working well
# Page 1657 is working well
# Page 1658 is working well
# Page 1659 is working well
# Page 1660 is working well
# Page 1661 is working well
# Page 1662 is working well
# Page 1663 is working well
# Page 1664 is working well
# Page 1665 is working well
# Page 1666 is working well
# Page 1667 is working well
# Page 1668 is working well
# Page 1669 is working well
# Page 1670 is working well
# Page 1671 is working well
# Page 1672 is working well
# Page 1673 is working well
# Page 1674 is working well
# Page 1675 is working well
# Page 1676 is working well
# Page 1677 is working well
# Page 1678 is working well
# Page 1679 is working well
# Page 1680 is working well
# Page 1681 is working well
# Page 1682 is working well
# Page 1683 is working well
# Page 1684 is working well
# Page 1685 is working well
# Page 1686 is working well
# Page 1687 is working well
# Page 1688 is working well
# Page 1689 is working well
# Page 1690 is working well
# Page 1691 is working well
# Page 1692 is working well
# Page 1693 is working well
# Page 1694 is working well
# Page 1695 is working well
# Page 1696 is working well
# Page 1697 is working well
# Page 1698 is working well
# Page 1699 is working well
# Page 1700 is working well
# Page 1701 is working well
# Page 1702 is working well
# Page 1703 is working well
# Page 1704 is working well
# Page 1705 is working well
# Page 1706 is working well
# Page 1707 is working well
# Page 1708 is working well
# Page 1709 is working well
# Page 1710 is working well
# Page 1711 is working well
# Page 1712 is working well
# Page 1713 is working well
# Page 1714 is working well
# Page 1715 is working well
# Page 1716 is working well
# Page 1717 is working well
# Page 1718 is working well
# Page 1719 is working well
# Page 1720 is working well
# Page 1721 is working well
# Page 1722 is working well
# Page 1723 is working well
# Page 1724 is working well
# Page 1725 is working well
# Page 1726 is working well
# Page 1727 is working well
# Page 1728 is working well
# Page 1729 is working well
# Page 1730 is working well
# Page 1731 is working well
# Page 1732 is working well
# Page 1733 is working well
# Page 1734 is working well
# Page 1735 is working well
# Page 1736 is working well
# Page 1737 is working well
# Page 1738 is working well
# Page 1739 is working well
# Page 1740 is working well
# Page 1741 is working well
# Page 1742 is working well
# Page 1743 is working well
# Page 1744 is working well
# Page 1745 is working well
# Page 1746 is working well
# Page 1747 is working well
# Page 1748 is working well
# Page 1749 is working well
# Page 1750 is working well
# Page 1751 is working well
# Page 1752 is working well
# Page 1753 is working well
# Page 1754 is working well
# Page 1755 is working well
# Page 1756 is working well
# Page 1757 is working well
# Page 1758 is working well
# Page 1759 is working well
# Page 1760 is working well
# Page 1761 is working well
# Page 1762 is working well
# Page 1763 is working well
# Page 1764 is working well
# Page 1765 is working well
# Page 1766 is working well
# Page 1767 is working well
# Page 1768 is working well
# Page 1769 is working well
# Page 1770 is working well
# Page 1771 is working well
# Page 1772 is working well
# Page 1773 is working well
# Page 1774 is working well
# Page 1775 is working well
# Page 1776 is working well
# Page 1777 is working well
# Page 1778 is working well
# Page 1779 is working well
# Page 1780 is working well
# Page 1781 is working well
# Page 1782 is working well
# Page 1783 is working well
# Page 1784 is working well
# Page 1785 is working well
# Page 1786 is working well
# Page 1787 is working well
# Page 1788 is working well
# Page 1789 is working well
# Page 1790 is working well
# Page 1791 is working well
# Page 1792 is working well
# Page 1793 is working well
# Page 1794 is working well
# Page 1795 is working well
# Page 1796 is working well
# Page 1797 is working well
# Page 1798 is working well
# Page 1799 is working well
# Page 1800 is working well
# Page 1801 is working well
# Page 1802 is working well
# Page 1803 is working well
# Page 1804 is working well
# Page 1805 is working well
# Page 1806 is working well
# Page 1807 is working well
# Page 1808 is working well
# Page 1809 is working well
# Page 1810 is working well
# Page 1811 is working well
# Page 1812 is working well
# Page 1813 is working well
# Page 1814 is working well
# Page 1815 is working well
# Page 1816 is working well
# Page 1817 is working well
# Page 1818 is working well
# Page 1819 is working well
# Page 1820 is working well
# Page 1821 is working well
# Page 1822 is working well
# Page 1823 is working well
# Page 1824 is working well
# Page 1825 is working well
# Page 1826 is working well
# Page 1827 is working well
# Page 1828 is working well
# Page 1829 is working well
# Page 1830 is working well
# Page 1831 is working well
# Page 1832 is working well
# Page 1833 is working well
# Page 1834 is working well
# Page 1835 is working well
# Page 1836 is working well
# Page 1837 is working well
# Page 1838 is working well
# Page 1839 is working well
# Page 1840 is working well
# Page 1841 is working well
# Page 1842 is working well
# Page 1843 is working well
# Page 1844 is working well
# Page 1845 is working well
# Page 1846 is working well
# Page 1847 is working well
# Page 1848 is working well
# Page 1849 is working well
# Page 1850 is working well
# Page 1851 is working well
# Page 1852 is working well
# Page 1853 is working well
# Page 1854 is working well
# Page 1855 is working well
# Page 1856 is working well
# Page 1857 is working well
# Page 1858 is working well
# Page 1859 is working well
# Page 1860 is working well
# Page 1861 is working well
# Page 1862 is working well
# Page 1863 is working well
# Page 1864 is working well
# Page 1865 is working well
# Page 1866 is working well
# Page 1867 is working well
# Page 1868 is working well
# Page 1869 is working well
# Page 1870 is working well
# Page 1871 is working well
# Page 1872 is working well
# Page 1873 is working well
# Page 1874 is working well
# Page 1875 is working well
# Page 1876 is working well
# Page 1877 is working well
# Page 1878 is working well
# Page 1879 is working well
# Page 1880 is working well
# Page 1881 is working well
# Page 1882 is working well
# Page 1883 is working well
# Page 1884 is working well
# Page 1885 is working well
# Page 1886 is working well
# Page 1887 is working well
# Page 1888 is working well
# ...
# Page 8368 is working well
# Page 8369 is working well
# Page 8370 is working well
# Page 8371 is working well
# Page 8372 is working well
# Page 8373 is working well
# Page 8374 is working well
# Page 8375 is working well
# Page 8376 is working well
# Page 8377 is working well
# Page 8378 is working well
# Page 8379 is working well
# Page 8380 is working well
# Page 8381 is working well
# Page 8382 is working well
# Page 8383 is working well
# Page 8384 is working well
# Page 8385 is working well
# Page 8386 is working well
# Page 8387 is working well
# Page 8388 is working well
# Page 8389 is working well
# Page 8390 is working well
# Page 8391 is working well
# Page 8392 is working well
# Page 8393 is working well
# Page 8394 is working well
# Page 8395 is working well
# Page 8396 is working well
# Page 8397 is working well
# Page 8398 is working well
# Page 8399 is working well
# Page 8400 is working well
# Page 8401 is working well
# Page 8402 is working well
# Page 8403 is working well
# Page 8404 is working well
# Page 8405 is working well
# Page 8406 is working well
# Page 8407 is working well
# Page 8408 is working well
# Page 8409 is working well
# Page 8410 is working well
# Page 8411 is working well
# Page 8412 is working well
# Page 8413 is working well
# Page 8414 is working well
# Page 8415 is working well
# Page 8416 is working well
# Page 8417 is working well
# Page 8418 is working well
# Page 8419 is working well
# Page 8420 is working well
# Page 8421 is working well
# Page 8422 is working well
# Page 8423 is working well
# Page 8424 is working well
# Page 8425 is working well
# Page 8426 is working well
# Page 8427 is working well
# Page 8428 is working well
# Page 8429 is working well
# Page 8430 is working well
# Page 8431 is working well
# Page 8432 is working well
# Page 8433 is working well
# Page 8434 is working well
# Page 8435 is working well
# Page 8436 is working well
# Page 8437 is working well
# Page 8438 is working well
# Page 8439 is working well
# Page 8440 is working well
# Page 8441 is working well
# Page 8442 is working well
# Page 8443 is working well
# Page 8444 is working well
# Page 8445 is working well
# Page 8446 is working well
# Page 8447 is working well
# Page 8448 is working well
# Page 8449 is working well
# Page 8450 is working well
# Page 8451 is working well
# Page 8452 is working well
# Page 8453 is working well
# Page 8454 is working well
# Page 8455 is working well
# Page 8456 is working well
# Page 8457 is working well
# Page 8458 is working well
# Page 8459 is working well
# Page 8460 is working well
# Page 8461 is working well
# Page 8462 is working well
# Page 8463 is working well
# Page 8464 is working well
# Page 8465 is working well
# Page 8466 is working well
# Page 8467 is working well
# Page 8468 is working well
# Page 8469 is working well
# Page 8470 is working well
# Page 8471 is working well
# Page 8472 is working well
# Page 8473 is working well
# Page 8474 is working well
# Page 8475 is working well
# Page 8476 is working well
# Page 8477 is working well
# Page 8478 is working well
# Page 8479 is working well
# Page 8480 is working well
# Page 8481 is working well
# Page 8482 is working well
# Page 8483 is working well
# Page 8484 is working well
# Page 8485 is working well
# Page 8486 is working well
# Page 8487 is working well
# Page 8488 is working well
# Page 8489 is working well
# Page 8490 is working well
# Page 8491 is working well
# Page 8492 is working well
# Page 8493 is working well
# Page 8494 is working well
# Page 8495 is working well
# Page 8496 is working well
# Page 8497 is working well
# Page 8498 is working well
# Page 8499 is working well
# Page 8500 is working well
# Page 8501 is working well
# Page 8502 is working well
# Page 8503 is working well
# Page 8504 is working well
# Page 8505 is working well
# Page 8506 is working well
# Page 8507 is working well
# Page 8508 is working well
# Page 8509 is working well
# Page 8510 is working well
# Page 8511 is working well
# Page 8512 is working well
# Page 8513 is working well
# Page 8514 is working well
# Page 8515 is working well
# Page 8516 is working well
# Page 8517 is working well
# Page 8518 is working well
# Page 8519 is working well
# Page 8520 is working well
# Page 8521 is working well
# Page 8522 is working well
# Page 8523 is working well
# Page 8524 is working well
# Page 8525 is working well
# Page 8526 is working well
# Page 8527 is working well
# Page 8528 is working well
# Page 8529 is working well
# Page 8530 is working well
# Page 8531 is working well
# Page 8532 is working well
# Page 8533 is working well
# Page 8534 is working well
# Page 8535 is working well
# Page 8536 is working well
# Page 8537 is working well
# Page 8538 is working well
# Page 8539 is working well
# Page 8540 is working well
# Page 8541 is working well
# Page 8542 is working well
# Page 8543 is working well
# Page 8544 is working well
# Page 8545 is working well
# Page 8546 is working well
# Page 8547 is working well
# Page 8548 is working well
# Page 8549 is working well
# Page 8550 is working well
# Page 8551 is working well
# Page 8552 is working well
# Page 8553 is working well
# Page 8554 is working well
# Page 8555 is working well
# Page 8556 is working well
# Page 8557 is working well
# Page 8558 is working well
# Page 8559 is working well
# Page 8560 is working well
# Page 8561 is working well
# Page 8562 is working well
# Page 8563 is working well
# Page 8564 is working well
# Page 8565 is working well
# Page 8566 is working well
# Page 8567 is working well
# Page 8568 is working well
# Page 8569 is working well
# Page 8570 is working well
# Page 8571 is working well
# Page 8572 is working well
# Page 8573 is working well
# Page 8574 is working well
# Page 8575 is working well
# Page 8576 is working well
# Page 8577 is working well
# Page 8578 is working well
# Page 8579 is working well
# Page 8580 is working well
# Page 8581 is working well
# Page 8582 is working well
# Page 8583 is working well
# Page 8584 is working well
# Page 8585 is working well
# Page 8586 is working well
# Page 8587 is working well
# Page 8588 is working well
# Page 8589 is working well
# Page 8590 is working well
# Page 8591 is working well
# Page 8592 is working well
# Page 8593 is working well
# Page 8594 is working well
# Page 8595 is working well
# Page 8596 is working well
# Page 8597 is working well
# Page 8598 is working well
# Page 8599 is working well
# Page 8600 is working well
# Page 8601 is working well
# Page 8602 is working well
# Page 8603 is working well
# Page 8604 is working well
# Page 8605 is working well
# Page 8606 is working well
# Page 8607 is working well
# Page 8608 is working well
# Page 8609 is working well
# Page 8610 is working well
# Page 8611 is working well
# Page 8612 is working well
# Page 8613 is working well
# Page 8614 is working well
# Page 8615 is working well
# Page 8616 is working well
# Page 8617 is working well
# Page 8618 is working well
# Page 8619 is working well
# Page 8620 is working well
# Page 8621 is working well
# Page 8622 is working well
# Page 8623 is working well
# Page 8624 is working well
# Page 8625 is working well
# Page 8626 is working well
# Page 8627 is working well
# Page 8628 is working well
# Page 8629 is working well
# Page 8630 is working well
# Page 8631 is working well
# Page 8632 is working well
# Page 8633 is working well
# Page 8634 is working well
# Page 8635 is working well
# Page 8636 is working well
# Page 8637 is working well
# Page 8638 is working well
# Page 8639 is working well
# Page 8640 is working well
# Page 8641 is working well
# Page 8642 is working well
# Page 8643 is working well
# Page 8644 is working well
# Page 8645 is working well
# Page 8646 is working well
# Page 8647 is working well
# Page 8648 is working well
# Page 8649 is working well
# Page 8650 is working well
# Page 8651 is working well
# Page 8652 is working well
# Page 8653 is working well
# Page 8654 is working well
# Page 8655 is working well
# Page 8656 is working well
# Page 8657 is working well
# Page 8658 is working well
# Page 8659 is working well
# Page 8660 is working well
# Page 8661 is working well
# Page 8662 is working well
# Page 8663 is working well
# Page 8664 is working well
# Page 8665 is working well
# Page 8666 is working well
# Page 8667 is working well
# Page 8668 is working well
# Page 8669 is working well
# Page 8670 is working well
# Page 8671 is working well
# Page 8672 is working well
# Page 8673 is working well
# Page 8674 is working well
# Page 8675 is working well
# Page 8676 is working well
# Page 8677 is working well
# Page 8678 is working well
# Page 8679 is working well
# Page 8680 is working well
# Page 8681 is working well
# Page 8682 is working well
# Page 8683 is working well
# Page 8684 is working well
# Page 8685 is working well
# Page 8686 is working well
# Page 8687 is working well
# Page 8688 is working well
# Page 8689 is working well
# Page 8690 is working well
# Page 8691 is working well
# Page 8692 is working well
# Page 8693 is working well
# Page 8694 is working well
# Page 8695 is working well
# Page 8696 is working well
# Page 8697 is working well
# Page 8698 is working well
# Page 8699 is working well
# Page 8700 is working well
# Page 8701 is working well
# Page 8702 is working well
# Page 8703 is working well
# Page 8704 is working well
# Page 8705 is working well
# Page 8706 is working well
# Page 8707 is working well
# Page 8708 is working well
# Page 8709 is working well
# Page 8710 is working well
# Page 8711 is working well
# Page 8712 is working well
# Page 8713 is working well
# Page 8714 is working well
# Page 8715 is working well
# Page 8716 is working well
# Page 8717 is working well
# Page 8718 is working well
# Page 8719 is working well
# Page 8720 is working well
# Page 8721 is working well
# Page 8722 is working well
# Page 8723 is working well
# Page 8724 is working well
# Page 8725 is working well
# Page 8726 is working well
# Page 8727 is working well
# Page 8728 is working well
# Page 8729 is working well
# Page 8730 is working well
# Page 8731 is working well
# Page 8732 is working well
# Page 8733 is working well
# Page 8734 is working well
# Page 8735 is working well
# Page 8736 is working well
# Page 8737 is working well
# Page 8738 is working well
# Page 8739 is working well
# Page 8740 is working well
# Page 8741 is working well
# Page 8742 is working well
# Page 8743 is working well
# Page 8744 is working well
# Page 8745 is working well
# Page 8746 is working well
# Page 8747 is working well
# Page 8748 is working well
# Page 8749 is working well
# Page 8750 is working well
# Page 8751 is working well
# Page 8752 is working well
# Page 8753 is working well
# Page 8754 is working well
# Page 8755 is working well
# Page 8756 is working well
# Page 8757 is working well
# Page 8758 is working well
# Page 8759 is working well
# Page 8760 is working well
# Page 8761 is working well
# Page 8762 is working well
# Page 8763 is working well
# Page 8764 is working well
# Page 8765 is working well
# Page 8766 is working well
# Page 8767 is working well
# Page 8768 is working well
# Page 8769 is working well
# Page 8770 is working well
# Page 8771 is working well
# Page 8772 is working well
# Page 8773 is working well
# Page 8774 is working well
# Page 8775 is working well
# Page 8776 is working well
# Page 8777 is working well
# Page 8778 is working well
# Page 8779 is working well
# Page 8780 is working well
# Page 8781 is working well
# Page 8782 is working well
# Page 8783 is working well
# Page 8784 is working well
# Page 8785 is working well
# Page 8786 is working well
# Page 8787 is working well
# Page 8788 is working well
# Page 8789 is working well
# Page 8790 is working well
# Page 8791 is working well
# Page 8792 is working well
# Page 8793 is working well
# Page 8794 is working well
# Page 8795 is working well
# Page 8796 is working well
# Page 8797 is working well
# Page 8798 is working well
# Page 8799 is working well
# Page 8800 is working well
# Page 8801 is working well
# Page 8802 is working well
# Page 8803 is working well
# Page 8804 is working well
# Page 8805 is working well
# Page 8806 is working well
# Page 8807 is working well
# Page 8808 is working well
# Page 8809 is working well
# Page 8810 is working well
# Page 8811 is working well
# Page 8812 is working well
# Page 8813 is working well
# Page 8814 is working well
# Page 8815 is working well
# Page 8816 is working well
# Page 8817 is working well
# Page 8818 is working well
# Page 8819 is working well
# Page 8820 is working well
# Page 8821 is working well
# Page 8822 is working well
# Page 8823 is working well
# Page 8824 is working well
# Page 8825 is working well
# Page 8826 is working well
# Page 8827 is working well
# Page 8828 is working well
# Page 8829 is working well
# Page 8830 is working well
# Page 8831 is working well
# Page 8832 is working well
# Page 8833 is working well
# Page 8834 is working well
# Page 8835 is working well
# Page 8836 is working well
# Page 8837 is working well
# Page 8838 is working well
# Page 8839 is working well
# Page 8840 is working well
# Page 8841 is working well
# Page 8842 is working well
# Page 8843 is working well
# Page 8844 is working well
# Page 8845 is working well
# Page 8846 is working well
# Page 8847 is working well
# Page 8848 is working well
# Page 8849 is working well
# Page 8850 is working well
# Page 8851 is working well
# Page 8852 is working well
# Page 8853 is working well
# Page 8854 is working well
# Page 8855 is working well
# Page 8856 is working well
# Page 8857 is working well
# Page 8858 is working well
# Page 8859 is working well
# Page 8860 is working well
# Page 8861 is working well
# Page 8862 is working well
# Page 8863 is working well
# Page 8864 is working well
# Page 8865 is working well
# Page 8866 is working well
# Page 8867 is working well
# Page 8868 is working well
# Page 8869 is working well
# Page 8870 is working well
# Page 8871 is working well
# Page 8872 is working well
# Page 8873 is working well
# Page 8874 is working well
# Page 8875 is working well
# Page 8876 is working well
# Page 8877 is working well
# Page 8878 is working well
# Page 8879 is working well
# Page 8880 is working well
# Page 8881 is working well
# Page 8882 is working well
# Page 8883 is working well
# Page 8884 is working well
# Page 8885 is working well
# Page 8886 is working well
# Page 8887 is working well
# Page 8888 is working well
# Page 8889 is working well
# Page 8890 is working well
# Page 8891 is working well
# Page 8892 is working well
# Page 8893 is working well
# Page 8894 is working well
# Page 8895 is working well
# Page 8896 is working well
# Page 8897 is working well
# Page 8898 is working well
# Page 8899 is working well
# Page 8900 is working well
# Page 8901 is working well
# Page 8902 is working well
# Page 8903 is working well
# Page 8904 is working well
# Page 8905 is working well
# Page 8906 is working well
# Page 8907 is working well
# Page 8908 is working well
# Page 8909 is working well
# Page 8910 is working well
# Page 8911 is working well
# Page 8912 is working well
# Page 8913 is working well
# Page 8914 is working well
# Page 8915 is working well
# Page 8916 is working well
# Page 8917 is working well
# Page 8918 is working well
# Page 8919 is working well
# Page 8920 is working well
# Page 8921 is working well
# Page 8922 is working well
# Page 8923 is working well
# Page 8924 is working well
# Page 8925 is working well
# Page 8926 is working well
# Page 8927 is working well
# Page 8928 is working well
# Page 8929 is working well
# Page 8930 is working well
# Page 8931 is working well
# Page 8932 is working well
# Page 8933 is working well
# Page 8934 is working well
# Page 8935 is working well
# Page 8936 is working well
# Page 8937 is working well
# Page 8938 is working well
# Page 8939 is working well
# Page 8940 is working well
# Page 8941 is working well
# Page 8942 is working well
# Page 8943 is working well
# Page 8944 is working well
# Page 8945 is working well
# Page 8946 is working well
# Page 8947 is working well
# Page 8948 is working well
# Page 8949 is working well
# Page 8950 is working well
# Page 8951 is working well
# Page 8952 is working well
# Page 8953 is working well
# Page 8954 is working well
# Page 8955 is working well
# Page 8956 is working well
# Page 8957 is working well
# Page 8958 is working well
# Page 8959 is working well
# Page 8960 is working well
# Page 8961 is working well
# Page 8962 is working well
# Page 8963 is working well
# Page 8964 is working well
# Page 8965 is working well
# Page 8966 is working well
# Page 8967 is working well
# Page 8968 is working well
# Page 8969 is working well
# Page 8970 is working well
# Page 8971 is working well
# Page 8972 is working well
# Page 8973 is working well
# Page 8974 is working well
# Page 8975 is working well
# Page 8976 is working well
# Page 8977 is working well
# Page 8978 is working well
# Page 8979 is working well
# Page 8980 is working well
# Page 8981 is working well
# Page 8982 is working well

# %%
df_flats = pd.DataFrame(flats_dict).T

# %%
df_flats = df_flats[['Lat', 'Lon', 'District', 'Small_district', 'Rooms', 'Price', 'Price_duplicate', 'Totsp', 'Livesp', \
                     'Kitsp', 'Dist', 'Stname', 'Metrdist', 'Walk', 'Brick', 'Tel', 'Bal', 'Floor', 'Nfloors', 'New', 'Link']]

# %% [markdown]
# ### Проверка результатов и корректировка

# %%
df_flats.describe()
# Out:
#          Bal  Brick         Dist  District  Floor  Kitsp          Lat  \
# count   8979   5180  8979.000000      8979   8977   8127  8979.000000
# unique     2      2  4821.000000        12     42    596  4821.000000
# top        1      0   735.566682         0      2     20    55.848943
# freq    6180   2765   118.000000       836   1182    485   118.000000
#
#                                            Link  Livesp          Lon  ...   \
# count                                      8979    4685  8979.000000  ...
# unique                                     8979     214  4776.000000  ...
# top     http://www.cian.ru/sale/flat/150052325/      10    37.578073  ...
# freq                                          1     776   117.000000  ...
#
#          New  Nfloors    Price  Price_duplicate  Rooms  Small_district  \
# count   8979     8875     8939             8979   8979            5180
# unique     2       53     3267             3301      6             142
# top        0        9  6500000          6500000      1          Троицк
# freq    6176     1333      145              145   4116             202
#
#              Stname   Tel  Totsp  Walk
# count          7754  8979   8979  7754
# unique          179     2    854     2
# top     Теплый Стан     0     38     1
# freq            469  6071    281  4960
#
# [4 rows x 21 columns]

# %%
for c in df_flats.columns:
    print(c, len(df_flats[c][df_flats[c].isnull()]))
# Out:
# Lat 0
# Lon 0
# District 0
# Small_district 3799
# Rooms 0
# Price 40
# Price_duplicate 0
# Totsp 0
# Livesp 4294
# Kitsp 852
# Dist 0
# Stname 1225
# Metrdist 1225
# Walk 1225
# Brick 3799
# Tel 0
# Bal 0
# Floor 2
# Nfloors 104
# New 0
# Link 0

# %%
df_flats.to_csv('sell_table_2.csv')

# %%
def check(l):
    
    flat_dict = {}
    
    # Это будет номер квартиры
    N = 0

    # Соберем все, что написано выше, вместе
    flat_page = requests.get(l[0])
    flat_page = flat_page.text
    flat_page = BeautifulSoup(flat_page, 'lxml')
    inf_table = flat_page.findAll('table', class_ = 'object_descr_tab')
    inf_table = inf_table[0]
    inner_table = inf_table.findAll('table', class_ = 'object_descr_props flat sale')
    inner_table = inner_table[0]

    house_coords = getCoords(flat_page)

    flat_dict[N] = {
        'Lat': house_coords[0],
        'Lon': house_coords[1],
        'District': l[1],
        'Rooms': room_grabber(inf_table),
        'Price': price_grabber(inf_table)[0],
        'Price_duplicate': price_grabber(inf_table)[1],
        'Totsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['totsp'],
        'Livesp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['kitsp'],
        'Kitsp': sp_grabber(inner_table, sp_pl = ['Общая площадь', 'Площадь кухни', 'Жилая площадь'])['livesp'],
        'Dist': dist_grabber(house_coords),
        'Stname': metro(inf_table)['stname'],
        'Metrdist': metro(inf_table)['metrdist'],
        'Walk': metro(inf_table)['walk'],
        'Brick': brick_grabber(flat_page),
        'Tel': tel_grabber(inner_table),
        'Bal': bal_grabber(inner_table),
        'Floor': floor_grabber(inner_table)['floor'],
        'Nfloors': floor_grabber(inner_table)['n_floor'],
        'New': new_grabber(inner_table),
        'Link': l[0]}
    
    return(flat_dict)
